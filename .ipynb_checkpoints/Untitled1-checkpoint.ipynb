# %%
import pandas as pd
from pandas.io.json import json_normalize
import numpy as np 
import matplotlib.pyplot as plt
import json, re, os
from ulConnect import getULData, convertDateToDate
from WatchDog import getAllSOH, getSOH, getPurchases
from datetime import datetime, timedelta
from pprint import pprint

# %%
r = getULData('Customers/','pageSize=1000')
cust_df = pd.read_json(json.dumps(r.json()['Items']))

# %%
print(cust_df[['CustomerCode', 'Guid']][cust_df.CustomerCode.str.contains('Inde')],
      cust_df[['CustomerCode', 'Guid']][cust_df.CustomerCode.str.contains('Morrell')],
      cust_df[['CustomerCode', 'Guid']][cust_df.CustomerCode.str.contains('Red')],
    cust_df[['CustomerCode', 'Guid']][cust_df.CustomerCode.str.contains('Milestone')])
# Out:
#     CustomerCode                                  Guid
# 116  Inde Studio  2c0d01c7-c492-4385-987b-8ad8cdd34416          CustomerCode                                  Guid
# 177  Morrell Builders  11f96960-a3e3-4f3d-9883-b707274afef0            CustomerCode                                  Guid
# 217  Red Stone Builders  f31ae7bd-b182-474e-b429-c91a07b2b567                          CustomerCode                                  Guid
# 173  Milestones Home Management, Inc.  51448e4e-3470-42fd-a9a9-5dde118e4efb

# %%
r = getULData('Suppliers/','pageSize=1000')
manf_df = pd.read_json(json.dumps(r.json()['Items']))

# %%
r = getULData('SalesOrders/','pageSize=1000&customerId=2c0d01c7-c492-4385-987b-8ad8cdd34416&startDate=2018-4-9&endDate=2018-12-31&orderStatus=Completed')
inde_so_df = pd.read_json(json.dumps(r.json()['Items']))

# %%
inde_so_df.OrderDate = inde_so_df.OrderDate.apply(convertDateToDate)
inde_so_df.CompletedDate = inde_so_df.CompletedDate.apply(convertDateToDate)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-de678bfd21ef> in <module>()
# ----> 1 inde_so_df.OrderDate = inde_so_df.OrderDate.apply(convertDateToDate)
#       2 inde_so_df.CompletedDate = inde_so_df.CompletedDate.apply(convertDateToDate)
#       3 inde_so_df[['OrderDate', 'CompletedDate']].info()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# ~/Documents/Projects/SDS Talks/Inventory Cost Control And Automation/ulConnect.py in convertDateToDate(date)
#      58         if date is not None:
#      59                 # strip off the UL Bullshit
# ---> 60                 date = re.sub('[/Date()/]','',date)
#      61                 date = datetime.utcfromtimestamp(int(date)/1000)
#      62         return(date)
#
# ~/anaconda3/lib/python3.7/re.py in sub(pattern, repl, string, count, flags)
#     190     a callable, it's passed the Match object and must return
#     191     a replacement string to be used."""
# --> 192     return _compile(pattern, flags).sub(repl, string, count)
#     193
#     194 def subn(pattern, repl, string, count=0, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
inde_so_df['Time_To_Complete'] = inde_so_df.CompletedDate - inde_so_df.OrderDate

# %%
inde_so_df[['OrderDate', 'CompletedDate', 'Time_To_Complete']].head(20)
# Out:
#              OrderDate           CompletedDate         Time_To_Complete
# 0  2018-11-28 23:00:00 2019-04-05 13:31:14.361 127 days 14:31:14.361000
# 1  2018-12-19 23:00:00 2019-03-11 20:24:39.703  81 days 21:24:39.703000
# 2  2018-12-11 23:00:00 2019-02-19 20:49:33.604  69 days 21:49:33.604000
# 3  2018-12-05 23:00:00 2019-02-18 18:37:05.692  74 days 19:37:05.692000
# 4  2018-12-04 23:00:00 2019-02-11 20:40:19.262  68 days 21:40:19.262000
# 5  2018-10-04 23:00:00 2019-02-05 18:46:08.027 123 days 19:46:08.027000
# 6  2018-11-16 23:00:00 2019-01-28 19:05:44.381  72 days 20:05:44.381000
# 7  2018-11-13 23:00:00 2019-01-04 18:58:09.068  51 days 19:58:09.068000
# 8  2018-09-20 23:00:00 2019-01-02 16:30:46.220 103 days 17:30:46.220000
# 9  2018-09-26 23:00:00 2019-01-02 15:57:25.388  97 days 16:57:25.388000
# 10 2018-10-26 23:00:00 2018-12-11 21:17:53.897  45 days 22:17:53.897000
# 11 2018-09-26 23:00:00 2018-12-06 14:36:23.136  70 days 15:36:23.136000
# 12 2018-10-01 23:00:00 2018-12-04 20:34:42.268  63 days 21:34:42.268000
# 13 2018-10-02 23:00:00 2018-11-30 19:23:18.567  58 days 20:23:18.567000
# 14 2018-09-06 23:00:00 2018-11-30 19:22:10.125  84 days 20:22:10.125000
# 15 2018-11-27 23:00:00 2018-11-28 13:31:35.568   0 days 14:31:35.568000
# 16 2018-08-31 23:00:00 2018-11-20 18:23:22.872  80 days 19:23:22.872000
# 17 2018-08-07 23:00:00 2018-11-20 18:22:00.718 104 days 19:22:00.718000
# 18 2018-11-01 23:00:00 2018-11-20 14:12:25.092  18 days 15:12:25.092000
# 19 2018-10-08 23:00:00 2018-11-16 16:39:02.903  38 days 17:39:02.903000

# %%
inde_so_df[inde_so_df.Time_To_Complete > timedelta(7)]['Time_To_Complete'].mean()
# Out:
# Timedelta('66 days 04:06:23.692260')

# %%
r = getULData('SalesOrders/','pageSize=1000&customerId=11f96960-a3e3-4f3d-9883-b707274afef0&startDate=2018-4-9&endDate=2019-3-1&orderStatus=Completed')
so_df = pd.read_json(json.dumps(r.json()['Items']))
so_df.OrderDate = so_df.OrderDate.apply(convertDateToDate)
so_df.CompletedDate = so_df.CompletedDate.apply(convertDateToDate)
so_df['Time_To_Complete'] = so_df.CompletedDate - so_df.OrderDate
so_df.Time_To_Complete.mean()
# Out:
# Timedelta('77 days 18:50:04.203428')

# %%
r = getULData('SalesOrders/','pageSize=1000&customerId=f31ae7bd-b182-474e-b429-c91a07b2b567&startDate=2018-4-9&endDate=2018-12-31&orderStatus=Completed')
so_df = pd.read_json(json.dumps(r.json()['Items']))
so_df.OrderDate = so_df.OrderDate.apply(convertDateToDate)
so_df.CompletedDate = so_df.CompletedDate.apply(convertDateToDate)
so_df['Time_To_Complete'] = so_df.CompletedDate - so_df.OrderDate
so_df.Time_To_Complete.mean()
# Out:
# Timedelta('26 days 21:23:40.578727')

# %%
r = getULData('SalesOrders/','pageSize=1000&customerId=11f96960-a3e3-4f3d-9883-b707274afef0&startDate=2018-4-9&endDate=2019-3-1&orderStatus=Completed')
so_df = pd.read_json(json.dumps(r.json()['Items']))
so_df.OrderDate = so_df.OrderDate.apply(convertDateToDate)
so_df.CompletedDate = so_df.CompletedDate.apply(convertDateToDate)
so_df['Time_To_Complete'] = so_df.CompletedDate - so_df.OrderDate
so_df.Time_To_Complete.mean()
# Out:
# Timedelta('77 days 18:50:04.203428')

# %%
print(manf_df[['SupplierName', 'SupplierCode','Guid']][manf_df.SupplierName.str.contains('WICK')],
      manf_df[['SupplierName', 'SupplierCode','Guid']][manf_df.SupplierName.str.contains('REAL WOO')],
      manf_df[['SupplierName', 'SupplierCode','Guid']][manf_df.SupplierName.str.contains('American O')])
# Out:
#                   SupplierName               SupplierCode  \
# 117  WICKHAM HARDWOOD FLOORING  WICKHAM HARDWOOD FLOORING
#
#                                      Guid
# 117  8b08e795-c905-4ddb-a072-c302f700a4b8           SupplierName      SupplierCode                                  Guid
# 94  REAL WOOD FLOORS  REAL WOOD FLOORS  ba48c6a8-fe8d-4c8f-b676-12e1ff706f02    SupplierName  SupplierCode                                  Guid
# 8  American OEM  American OEM  d320ea27-5022-44fe-b03a-7038f3e85d65

# %%
# r = getPurchases() #getULData('PurchaseOrders/','pageSize=1000')#&supplierCode=WICKHAM HARDWOOD FLOORING#&startDate=2018-4-9&endDate=2018-12-31')
po_df = pd.read_json(json.dumps(getPurchases()))
po_df.CreatedOn = po_df.CreatedOn.apply(convertDateToDate)
po_df.CompletedDate.dropna(inplace=True)
po_df.CompletedDate = po_df.CompletedDate.apply(convertDateToDate)
# so_df['Time_To_Complete'] = so_df.CreatedOn - so_df.OrderDate
# so_df.Time_To_Complete.mean()

# %%
po_df.head()
# Out:
#    BCSubTotal  BCTaxTotal  BCTotal Comments           CompletedDate  \
# 0     8006.86           0  8006.86     None 2018-04-09 19:11:28.862
# 1      440.00           0   440.00     None 2018-04-09 19:06:01.377
# 2     1428.48           0  1428.48     None 2018-04-23 21:00:11.599
# 3      432.00           0   432.00     None 2018-05-14 14:29:20.108
# 4     2201.92           0  2201.92     None 2018-04-25 15:33:59.356
#
#             CreatedBy               CreatedOn  \
# 0  jon@iwhardwood.com 2018-04-08 13:34:18.314
# 1  jon@iwhardwood.com 2018-04-08 13:35:52.611
# 2  sue@iwhardwood.com 2018-04-08 13:46:06.639
# 3  jon@iwhardwood.com 2018-04-08 13:49:57.109
# 4  jon@iwhardwood.com 2018-04-08 13:59:12.391
#
#                                             Currency DeliveryCity  \
# 0  {'CurrencyCode': 'USD', 'Description': 'United...    Rochester
# 1  {'CurrencyCode': 'USD', 'Description': 'United...    Rochester
# 2  {'CurrencyCode': 'USD', 'Description': 'United...    Rochester
# 3  {'CurrencyCode': 'USD', 'Description': 'United...    Rochester
# 4  {'CurrencyCode': 'USD', 'Description': 'United...    Rochester
#
#   DeliveryCountry  ...    SupplierInvoiceDate  SupplierRef  \
# 0            None  ...  /Date(1523246400000)/        S3319
# 1            None  ...  /Date(1522900800000)/        S3319
# 2            None  ...  /Date(1523419200000)/       189124
# 3            None  ...  /Date(1526011200000)/        S3421
# 4            None  ...  /Date(1523937600000)/        41781
#
#                                                  Tax TaxRate TaxTotal  \
# 0  {'TaxCode': 'NONE', 'Description': None, 'TaxR...       0        0
# 1  {'TaxCode': 'NONE', 'Description': None, 'TaxR...       0        0
# 2  {'TaxCode': 'NONE', 'Description': None, 'TaxR...       0        0
# 3  {'TaxCode': 'NONE', 'Description': None, 'TaxR...       0        0
# 4  {'TaxCode': 'NONE', 'Description': None, 'TaxR...       0        0
#
#      Total  TotalVolume  TotalWeight  \
# 0  8006.86            0            0
# 1   440.00            0            0
# 2  1428.48            0            0
# 3   432.00            0            0
# 4  2201.92            0            0
#
#                                            Warehouse XeroTaxCode
# 0  {'WarehouseCode': 'IW', 'WarehouseName': 'Inst...        NONE
# 1  {'WarehouseCode': 'IW', 'WarehouseName': 'Inst...        NONE
# 2  {'WarehouseCode': 'IW', 'WarehouseName': 'Inst...        NONE
# 3  {'WarehouseCode': 'IW', 'WarehouseName': 'Inst...        NONE
# 4  {'WarehouseCode': 'IW', 'WarehouseName': 'Inst...        NONE
#
# [5 rows x 41 columns]

# %%
po_df = po_df[~po_df.CompletedDate.isna()]
po_df['Time_To_Complete'] = po_df.CompletedDate - po_df.CreatedOn

# %%
po_df = po_df[['Supplier', 'CreatedOn', 'CompletedDate', 'Time_To_Complete']]

# %%
po_df.head()
# Out:
#                                             Supplier               CreatedOn  \
# 0  {'Guid': 'd320ea27-5022-44fe-b03a-7038f3e85d65... 2018-04-08 13:34:18.314
# 1  {'Guid': 'd320ea27-5022-44fe-b03a-7038f3e85d65... 2018-04-08 13:35:52.611
# 2  {'Guid': '997d9738-72e7-4d21-a648-32d763dd990e... 2018-04-08 13:46:06.639
# 3  {'Guid': 'd320ea27-5022-44fe-b03a-7038f3e85d65... 2018-04-08 13:49:57.109
# 4  {'Guid': '0871166d-a9b7-439c-afdf-3f67c82ba5c4... 2018-04-08 13:59:12.391
#
#             CompletedDate        Time_To_Complete
# 0 2018-04-09 19:11:28.862  1 days 05:37:10.548000
# 1 2018-04-09 19:06:01.377  1 days 05:30:08.766000
# 2 2018-04-23 21:00:11.599 15 days 07:14:04.960000
# 3 2018-05-14 14:29:20.108 36 days 00:39:22.999000
# 4 2018-04-25 15:33:59.356 17 days 01:34:46.965000

# %%
po_df = pd.concat([po_df, json_normalize(po_df.Supplier)], axis=1)

# %%
po_df.SupplierCode.dropna(inplace=True)
po_df.to_csv()

# %%
print(po_df[po_df.SupplierName == 'WICKHAM HARDWOOD FLOORING']['Time_To_Complete'].mean(), '\n',
po_df[po_df.SupplierName == 'REAL WOOD FLOORS']['Time_To_Complete'].mean(),'\n',
po_df[po_df.SupplierName == 'American OEM']['Time_To_Complete'].mean())
print(po_df[po_df.SupplierName == 'WICKHAM HARDWOOD FLOORING']['Time_To_Complete'].std(), '\n',
po_df[po_df.SupplierName == 'REAL WOOD FLOORS']['Time_To_Complete'].std(),'\n',
po_df[po_df.SupplierName == 'American OEM']['Time_To_Complete'].std())
# Out:
# 16 days 10:03:20.624115
#  12 days 19:21:45.422590
#  24 days 19:33:15.323666
# 10 days 20:16:54.973582
#  14 days 20:23:12.943657
#  19 days 18:25:34.988004

# %% [markdown]
# ### We see here that the amount of time we have orders in our system and the amount of time it takes to receive these orderes from the manufacturers are quite different.

# %% [markdown]
# ### Now we build a system that will allow us to reduce the time period we are holding onto material for a customer

# %% [markdown]
# #### Step 1) Understand the status flag for sales orders:

# %% [markdown]
# A sales order can be in either "Parked", "Placed", or "Backoredered" status. We use each of these states for something very specific:
#
# A Placed order is in stock, and ready to be delivered any time
# A Backordered order is one where some, or all, of the materail on the sales order has to be ordered from the manufacturer, is currently on a Purchase order, and is being made at the manufacturing facility.
# A Parked order is one where we will need to order some materail to fufil the order, but we have not placed that PO yet.

# %% [markdown]
# #### Step 2) Using that informaiton:

# %% [markdown]
# Our system will look for all Parked sales orders every day, calculate the mean time to fufill an order from the corresponding manufacturer, plus one standard deviation on that time, and make a determination on whether that order should be moved from Parked status to Backordered status, and subsequently purchased from the manufacturer
#
# The system makes this determination by checking if the time delta between the customer's required delivery date, and the current day is less than or equal to the mean time to receive an order + one standard deviation.
#
# If this is the case, an email is triggered letting the inside sales team know to place the order.

# %% [markdown]
# ## Get all sales orders in parked status:

# %%
# r = getULData('SalesOrders/', 'pageSize=1000&orderStatus=Parked')
r.json()
# Out:
# {'Pagination': {'NumberOfItems': 16,
#   'PageSize': 1000,
#   'PageNumber': 1,
#   'NumberOfPages': 1},
#  'Items': [{'SalesOrderLines': [{'LineNumber': 1,
#      'LineType': None,
#      'Product': {'Guid': '876df01f-8f1c-437e-9cec-a3d1b96368e9',
#       'ProductCode': 'ZinUniSea5Gal',
#       'ProductDescription': 'Universal Sealer 5 Gal Sealcoat'},
#      'DueDate': '/Date(1564672510890)/',
#      'OrderQuantity': 3.0,
#      'UnitPrice': 185.89,
#      'DiscountRate': 0.0,
#      'LineTotal': 557.67,
#      'Volume': None,
#      'Weight': None,
#      'Comments': '',
#      'AverageLandedPriceAtTimeOfSale': 132.29169444444443,
#      'TaxRate': 0.08,
#      'LineTax': 44.61,
#      'XeroTaxCode': 'Niagara County',
#      'BCUnitPrice': 185.89,
#      'BCLineTotal': 557.67,
#      'BCLineTax': 44.61,
#      'LineTaxCode': None,
#      'XeroSalesAccount': None,
#      'SerialNumbers': None,
#      'BatchNumbers': None,
#      'Guid': '475aabb4-45f8-4539-9f0f-fb727916d0f5',
#      'LastModifiedOn': '/Date(1564674342308)/'},
#     {'LineNumber': 2,
#      'LineType': None,
#      'Product': {'Guid': '532aa251-c9b1-4b57-9c2f-fe910ab89ed3',
#       'ProductCode': 'GLIWatMaxX2SAT',
#       'ProductDescription': 'GlitsaMax X2 SATIN'},
#      'DueDate': '/Date(1564672510890)/',
#      'OrderQuantity': 2.0,
#      'UnitPrice': 117.2899,
#      'DiscountRate': 0.0,
#      'LineTotal': 234.58,
#      'Volume': None,
#      'Weight': None,
#      'Comments': '',
#      'AverageLandedPriceAtTimeOfSale': 94.39333333333333,
#      'TaxRate': 0.08,
#      'LineTax': 18.77,
#      'XeroTaxCode': 'Niagara County',
#      'BCUnitPrice': 117.2899,
#      'BCLineTotal': 234.58,
#      'BCLineTax': 18.77,
#      'LineTaxCode': None,
#      'XeroSalesAccount': None,
#      'SerialNumbers': None,
#      'BatchNumbers': None,
#      'Guid': 'a81f30b9-7f05-49aa-b991-3a01db606e27',
#      'LastModifiedOn': '/Date(1564674928806)/'},
#     {'LineNumber': 3,
#      'LineType': None,
#      'Product': {'Guid': 'b30f9f8c-2894-4585-8284-0f15a918adc0',
#       'ProductCode': 'Pal96Sat',
#       'ProductDescription': 'Pallmann 96 1 Component SATIN 1 Gal'},
#      'DueDate': '/Date(1564672510890)/',
#      'OrderQuantity': 2.0,
#      'UnitPrice': 78.39,
#      'DiscountRate': 0.0,
#      'LineTotal': 156.78,
#      'Volume': None,
#      'Weight': None,
#      'Comments': '',
#      'AverageLandedPriceAtTimeOfSale': 49.91,
#      'TaxRate': 0.08,
#      'LineTax': 12.54,
#      'XeroTaxCode': 'Niagara County',
#      'BCUnitPrice': 78.39,
#      'BCLineTotal': 156.78,
#      'BCLineTax': 12.54,
#      'LineTaxCode': None,
#      'XeroSalesAccount': None,
#      'SerialNumbers': None,
#      'BatchNumbers': None,
#      'Guid': '6060b38a-dbda-4fc0-b581-febbf515a68d',
#      'LastModifiedOn': '/Date(1564672739678)/'},
#     {'LineNumber': 4,
#      'LineType': None,
#      'Product': {'Guid': '0dbd25e3-d479-493e-9811-0a09b784e34a',
#       'ProductCode': 'GLIWatINFSEM',
#       'ProductDescription': 'INFINITY II SEMI-GLOSS'},
#      'DueDate': '/Date(1564672510890)/',
#      'OrderQuantity': 2.0,
#      'UnitPrice': 64.89,
#      'DiscountRate': 0.0,
#      'LineTotal': 129.78,
#      'Volume': None,
#      'Weight': None,
#      'Comments': '',
#      'AverageLandedPriceAtTimeOfSale': 52.19625,
#      'TaxRate': 0.08,
#      'LineTax': 10.38,
#      'XeroTaxCode': 'Niagara County',
#      'BCUnitPrice': 64.89,
#      'BCLineTotal': 129.78,
#      'BCLineTax': 10.38,
#      'LineTaxCode': None,
#      'XeroSalesAccount': None,
#      'SerialNumbers': None,
#      'BatchNumbers': None,
#      'Guid': 'b07f277f-5a80-4099-9f0d-63fc51e7fb2a',
#      'LastModifiedOn': '/Date(1564672787720)/'},
#     {'LineNumber': 5,
#      'LineType': None,
#      'Product': {'Guid': 'ea73429d-ac47-44e2-af65-59916bb5c748',
#       'ProductCode': 'WooFT301D',
#       'ProductDescription': 'White Oak Powdered Wood Filler Bag'},
#      'DueDate': '/Date(1564672510890)/',
#      'OrderQuantity': 2.0,
#      'UnitPrice': 29.1899,
#      'DiscountRate': 0.0,
#      'LineTotal': 58.38,
#      'Volume': None,
#      'Weight': None,
#      'Comments': '',
#      'AverageLandedPriceAtTimeOfSale': 18.55630434782609,
#      'TaxRate': 0.08,
#      'LineTax': 4.67,
#      'XeroTaxCode': 'Niagara County',
#      'BCUnitPrice': 29.1899,
#      'BCLineTotal': 58.38,
#      'BCLineTax': 4.67,
#      'LineTaxCode': None,
#      'XeroSalesAccount': None,
#      'SerialNumbers': None,
#      'BatchNumbers': None,
#      'Guid': '255e0323-e038-4e3b-accd-8b623443391b',
#      'LastModifiedOn': '/Date(1564672834819)/'}],
#    'OrderNumber': 'SO-00005650',
#    'OrderDate': '/Date(1564672510889)/',
#    'RequiredDate': '/Date(1564672510889)/',
#    'CompletedDate': None,
#    'OrderStatus': 'Parked',
#    'Customer': {'CustomerCode': 'JAZZ HARDWOOD',
#     'CustomerName': 'JAZZ HARDWOOD',
#     'CurrencyId': 151,
#     'Guid': 'dee8493a-4194-44b0-9bd9-fd71e1811853',
#     'LastModifiedOn': '/Date(1561398981356)/'},
#    'CustomerRef': None,
#    'Comments': None,
#    'Warehouse': {'WarehouseCode': 'IW',
#     'WarehouseName': 'Installers Warehouse',
#     'IsDefault': True,
#     'StreetNo': 'Installers Warehouse, Inc.',
#     'AddressLine1': '1677C Lyell Ave.',
#     'AddressLine2': None,
#     'Suburb': None,
#     'City': 'Rochester',
#     'Region': 'NY',
#     'Country': None,
#     'PostCode': '14606',
#     'PhoneNumber': None,
#     'FaxNumber': None,
#     'MobileNumber': None,
#     'DDINumber': None,
#     'ContactName': None,
#     'Obsolete': False,
#     'Guid': 'f8aedb90-413a-4628-b1e4-80b609abe455',
#     'LastModifiedOn': '/Date(1555075989301)/'},
#    'ReceivedDate': None,
#    'DeliveryName': None,
#    'DeliveryStreetAddress': None,
#    'DeliveryStreetAddress2': None,
#    'DeliverySuburb': None,
#    'DeliveryCity': None,
#    'DeliveryRegion': None,
#    'DeliveryCountry': None,
#    'DeliveryPostCode': None,
#    'Currency': {'CurrencyCode': 'USD',
#     'Description': 'United States of America, Dollars',
#     'Guid': '8e4702ad-594b-4e80-9e0c-bfe77b8aa9f6',
#     'LastModifiedOn': '/Date(1513109457456)/'},
#    'ExchangeRate': 1.0,
#    'DiscountRate': 0.0,
#    'Tax': {'TaxCode': 'Niagara County',
#     'Description': None,
#     'TaxRate': 0.08,
#     'CanApplyToExpenses': False,
#     'CanApplyToRevenue': False,
#     'Obsolete': False,
#     'Guid': '00000000-0000-0000-0000-000000000000',
#     'LastModifiedOn': None},
#    'TaxRate': 0.08,
#    'XeroTaxCode': 'Niagara County',
#    'SubTotal': 1137.19,
#    'TaxTotal': 90.97,
#    'Total': 1228.16,
#    'TotalVolume': 0.0,
#    'TotalWeight': 0.0,
#    'BCSubTotal': 1137.19,
#    'BCTaxTotal': 90.97,
#    'BCTotal': 1228.16,
#    'PaymentDueDate': None,
#    'AllocateProduct': True,
#    'SalesOrderGroup': None,
#    'DeliveryMethod': None,
#    'SalesPerson': None,
#    'SendAccountingJournalOnly': False,
#    'SourceId': None,
#    'CreatedBy': 'jon@iwhardwood.com',
#    'CreatedOn': '/Date(1564672510904)/',
#    'LastModifiedBy': 'jon@iwhardwood.com',
#    'Guid': '37ecf0b0-e266-40d2-83de-78f3c599bf15',
#    'LastModifiedOn': '/Date(1564674928822)/'},
#   {'SalesOrderLines': [{'LineNumber': 1,
#      'LineType': None,
#      'Product': {'Guid': '95437681-d17c-456d-a2f0-b11c9b970ec1',
#       'ProductCode': 'WicAshCan3PyrMat',
#       'ProductDescription': "Can+  Ash 3.25' Pyramide MATTE"},
#      'DueDate': '/Date(1564584520266)/',
#      'OrderQuantity': 860.0,
#      'UnitPrice': 3.59,
#      'DiscountRate': 0.0,
#      'LineTotal': 3087.4,
#      'Volume': None,
#      'Weight': None,
#      'Comments': '',
#      'AverageLandedPriceAtTimeOfSale': 2.80085135135135,
#      'TaxRate': 0.075,
#      'LineTax': 231.56,
#      'XeroTaxCode': 'Ontario County',
#      'BCUnitPrice': 3.59,
#      'BCLineTotal': 3087.4,
#      'BCLineTax': 231.56,
#      'LineTaxCode': None,
#      'XeroSalesAccount': 'Sales',
#      'SerialNumbers': None,
#      'BatchNumbers': None,
#      'Guid': 'e66fab79-1584-48b4-8a07-8f22eb551b28',
#      'LastModifiedOn': '/Date(1564584844385)/'},
#     {'LineNumber': 2,
#      'LineType': None,
#      'Product': {'Guid': '8da1abb5-3d75-4766-a778-b5f660b603ce',
#       'ProductCode': 'ForUndAQU',
#       'ProductDescription': 'AQUABAR'},
#      'DueDate': '/Date(1564584520266)/',
#      'OrderQuantity': 2.0,
#      'UnitPrice': 20.59,
#      'DiscountRate': 0.0,
#      'LineTotal': 41.18,
#      'Volume': None,
#      'Weight': None,
#      'Comments': '',
#      'AverageLandedPriceAtTimeOfSale': 14.93943555555556,
#      'TaxRate': 0.075,
#      'LineTax': 3.09,
#      'XeroTaxCode': 'Ontario County',
#      'BCUnitPrice': 20.59,
#      'BCLineTotal': 41.18,
#      'BCLineTax': 3.09,
#      'LineTaxCode': None,
#      'XeroSalesAccount': 'Sales',
#      'SerialNumbers': None,
#      'BatchNumbers': None,
#      'Guid': 'b5270a9b-ab17-41d2-b069-1cd5fa56713f',
#      'LastModifiedOn': '/Date(1564584844385)/'},
#     {'LineNumber': 3,
#      'LineType': None,
#      'Product': {'Guid': '38f03170-ae4c-469b-b5f7-631db900d10b',
#       'ProductCode': 'WicTouPyr',
#       'ProductDescription': 'Touch Up Kit Pyramide'},
#      'DueDate': '/Date(1564584520266)/',
#      'OrderQuantity': 1.0,
#      'UnitPrice': 26.59,
#      'DiscountRate': 0.0,
#      'LineTotal': 26.59,
#      'Volume': None,
#      'Weight': None,
#      'Comments': '',
#      'AverageLandedPriceAtTimeOfSale': 20.36,
#      'TaxRate': 0.075,
#      'LineTax': 1.99,
#      'XeroTaxCode': 'Ontario County',
#      'BCUnitPrice': 26.59,
#      'BCLineTotal': 26.59,
#      'BCLineTax': 1.99,
#      'LineTaxCode': None,
#      'XeroSalesAccount': 'Sales',
#      'SerialNumbers': None,
#      'BatchNumbers': None,
#      'Guid': '68285b90-faaf-4718-b6ea-10c50a1ed5d0',
#      'LastModifiedOn': '/Date(1564584844385)/'},
#     {'LineNumber': 4,
#      'LineType': None,
#      'Product': {'Guid': '870f5f20-6408-4ff3-a944-45c4744ceb6b',
#       'ProductCode': 'Delivery',
#       'ProductDescription': 'Delivery Fee'},
#      'DueDate': '/Date(1564584520266)/',
#      'OrderQuantity': 1.0,
#      'UnitPrice': 85.0,
#      'DiscountRate': 0.0,
#      'LineTotal': 85.0,
#      'Volume': None,
#      'Weight': None,
#      'Comments': '',
#      'AverageLandedPriceAtTimeOfSale': 0.0,
#      'TaxRate': 0.075,
#      'LineTax': 6.38,
#      'XeroTaxCode': 'Ontario County',
#      'BCUnitPrice': 85.0,
#      'BCLineTotal': 85.0,
#      'BCLineTax': 6.38,
#      'LineTaxCode': None,
#      'XeroSalesAccount': 'Sales',
#      'SerialNumbers': None,
#      'BatchNumbers': None,
#      'Guid': '6921a914-d70a-4e90-9196-ae542637c37b',
#      'LastModifiedOn': '/Date(1564584844385)/'}],
#    'OrderNumber': 'SO-00005628',
#    'OrderDate': '/Date(1564614000000)/',
#    'RequiredDate': '/Date(1569020400000)/',
#    'CompletedDate': None,
#    'OrderStatus': 'Parked',
#    'Customer': {'CustomerCode': 'Pridemark Homes',
#     'CustomerName': 'Pridemark Homes',
#     'CurrencyId': 151,
#     'Guid': '06ae72ae-a0cc-4830-8f50-fb79d91e6cec',
#     'LastModifiedOn': '/Date(1564760512625)/'},
#    'CustomerRef': 'Lot 20 Hamilton Place',
#    'Comments': None,
#    'Warehouse': {'WarehouseCode': 'IW',
#     'WarehouseName': 'Installers Warehouse',
#     'IsDefault': True,
#     'StreetNo': 'Installers Warehouse, Inc.',
#     'AddressLine1': '1677C Lyell Ave.',
#     'AddressLine2': None,
#     'Suburb': None,
#     'City': 'Rochester',
#     'Region': 'NY',
#     'Country': None,
#     'PostCode': '14606',
#     'PhoneNumber': None,
#     'FaxNumber': None,
#     'MobileNumber': None,
#     'DDINumber': None,
#     'ContactName': None,
#     'Obsolete': False,
#     'Guid': 'f8aedb90-413a-4628-b1e4-80b609abe455',
#     'LastModifiedOn': '/Date(1555075989301)/'},
#    'ReceivedDate': None,
#    'DeliveryName': None,
#    'DeliveryStreetAddress': 'Lot 20 Hamilton Place',
#    'DeliveryStreetAddress2': '1320-1989',
#    'DeliverySuburb': None,
#    'DeliveryCity': None,
#    'DeliveryRegion': None,
#    'DeliveryCountry': None,
#    'DeliveryPostCode': None,
#    'Currency': {'CurrencyCode': 'USD',
#     'Description': 'United States of America, Dollars',
#     'Guid': '8e4702ad-594b-4e80-9e0c-bfe77b8aa9f6',
#     'LastModifiedOn': '/Date(1513109457456)/'},
#    'ExchangeRate': 1.0,
#    'DiscountRate': 0.0,
#    'Tax': {'TaxCode': 'Ontario County',
#     'Description': None,
#     'TaxRate': 0.075,
#     'CanApplyToExpenses': False,
#     'CanApplyToRevenue': False,
#     'Obsolete': False,
#     'Guid': '00000000-0000-0000-0000-000000000000',
#     'LastModifiedOn': None},
#    'TaxRate': 0.075,
#    'XeroTaxCode': 'Ontario County',
#    'SubTotal': 3240.17,
#    'TaxTotal': 243.02,
#    'Total': 3483.19,
#    'TotalVolume': 0.0,
#    'TotalWeight': 0.0,
#    'BCSubTotal': 3240.17,
#    'BCTaxTotal': 243.02,
#    'BCTotal': 3483.19,
#    'PaymentDueDate': '/Date(1567162444354)/',
#    'AllocateProduct': True,
#    'SalesOrderGroup': None,
#    'DeliveryMethod': None,
#    'SalesPerson': None,
#    'SendAccountingJournalOnly': False,
#    'SourceId': None,
#    'CreatedBy': 'dave@iwhardwood.com',
#    'CreatedOn': '/Date(1564584520282)/',
#    'LastModifiedBy': 'dave@iwhardwood.com',
#    'Guid': 'fa79438b-5a2b-44b2-aa1a-3054d6872420',
#    'LastModifiedOn': '/Date(1564584844385)/'},
#   {'SalesOrderLines': [{'LineNumber': 1,
#      'LineType': None,
#      'Product': {'Guid': '2e70bfed-c1d8-4952-b671-2277a86d480a',
#       'ProductCode': 'GriROIns410',
#       'ProductDescription': '4 X 10 R/O Ins Trimline'},
#      'DueDate': '/Date(1564492440813)/',
#      'OrderQuantity': 5.0,
#      'UnitPrice': 16.1899,
#      'DiscountRate': 0.0,
#      'LineTotal': 80.95,
#      'Volume': None,
#      'Weight': None,
#      'Comments': '',
#      'AverageLandedPriceAtTimeOfSale': 13.80182352941176,
#      'TaxRate': 0.0,
#      'LineTax': 0.0,
#      'XeroTaxCode': 'NONE',
#      'BCUnitPrice': 16.1899,
#      'BCLineTotal': 80.95,
#      'BCLineTax': 0.0,
#      'LineTaxCode': None,
#      'XeroSalesAccount': 'Sales',
#      'SerialNumbers': None,
#      'BatchNumbers': None,
#      'Guid': '1b113b80-7de2-442c-9a63-2fda7d9c5037',
#      'LastModifiedOn': '/Date(1564492513438)/'}],
#    'OrderNumber': 'SO-00005616',
#    'OrderDate': '/Date(1564527600000)/',
#    'RequiredDate': '/Date(1564527600000)/',
#    'CompletedDate': None,
#    'OrderStatus': 'Parked',
#    'Customer': {'CustomerCode': 'Messner Flooring America',
#     'CustomerName': 'Messner Flooring America',
#     'CurrencyId': 151,
#     'Guid': '0d26cd59-208e-47af-bc48-da3e002dc719',
#     'LastModifiedOn': '/Date(1561127335524)/'},
#    'CustomerRef': 'Leuschener',
#    'Comments': None,
#    'Warehouse': {'WarehouseCode': 'IW',
#     'WarehouseName': 'Installers Warehouse',
#     'IsDefault': True,
#     'StreetNo': 'Installers Warehouse, Inc.',
#     'AddressLine1': '1677C Lyell Ave.',
#     'AddressLine2': None,
#     'Suburb': None,
#     'City': 'Rochester',
#     'Region': 'NY',
#     'Country': None,
#     'PostCode': '14606',
#     'PhoneNumber': None,
#     'FaxNumber': None,
#     'MobileNumber': None,
#     'DDINumber': None,
#     'ContactName': None,
#     'Obsolete': False,
#     'Guid': 'f8aedb90-413a-4628-b1e4-80b609abe455',
#     'LastModifiedOn': '/Date(1555075989301)/'},
#    'ReceivedDate': None,
#    'DeliveryName': None,
#    'DeliveryStreetAddress': None,
#    'DeliveryStreetAddress2': None,
#    'DeliverySuburb': None,
#    'DeliveryCity': None,
#    'DeliveryRegion': None,
#    'DeliveryCountry': None,
#    'DeliveryPostCode': None,
#    'Currency': {'CurrencyCode': 'USD',
#     'Description': 'United States of America, Dollars',
#     'Guid': '8e4702ad-594b-4e80-9e0c-bfe77b8aa9f6',
#     'LastModifiedOn': '/Date(1513109457456)/'},
#    'ExchangeRate': 1.0,
#    'DiscountRate': 0.0,
#    'Tax': {'TaxCode': 'NONE',
#     'Description': None,
#     'TaxRate': 0.0,
#     'CanApplyToExpenses': False,
#     'CanApplyToRevenue': False,
#     'Obsolete': False,
#     'Guid': '00000000-0000-0000-0000-000000000000',
#     'LastModifiedOn': None},
#    'TaxRate': 0.0,
#    'XeroTaxCode': 'NONE',
#    'SubTotal': 80.95,
#    'TaxTotal': 0.0,
#    'Total': 80.95,
#    'TotalVolume': 0.0,
#    'TotalWeight': 0.0,
#    'BCSubTotal': 80.95,
#    'BCTaxTotal': 0.0,
#    'BCTotal': 80.95,
#    'PaymentDueDate': '/Date(1567070113375)/',
#    'AllocateProduct': True,
#    'SalesOrderGroup': None,
#    'DeliveryMethod': None,
#    'SalesPerson': None,
#    'SendAccountingJournalOnly': False,
#    'SourceId': None,
#    'CreatedBy': 'dave@iwhardwood.com',
#    'CreatedOn': '/Date(1564492440829)/',
#    'LastModifiedBy': 'dave@iwhardwood.com',
#    'Guid': 'ddd7da87-4448-48d2-9a6d-388276bdb038',
#    'LastModifiedOn': '/Date(1564492513454)/'},
#   {'SalesOrderLines': [{'LineNumber': 1,
#      'LineType': None,
#      'Product': {'Guid': 'cefc9904-2d31-4d84-bd82-d6df1b9d56dc',
#       'ProductCode': 'MetGen600Wea',
#       'ProductDescription': 'Genesis 600 Weathered'},
#      'DueDate': '/Date(1564408903603)/',
#      'OrderQuantity': 915.75,
#      'UnitPrice': 2.99,
#      'DiscountRate': 0.0,
#      'LineTotal': 2738.09,
#      'Volume': None,
#      'Weight': None,
#      'Comments': '',
#      'AverageLandedPriceAtTimeOfSale': 1.87430088766452,
#      'TaxRate': 0.08,
#      'LineTax': 219.05,
#      'XeroTaxCode': 'Steuben County',
#      'BCUnitPrice': 2.99,
#      'BCLineTotal': 2738.09,
#      'BCLineTax': 219.05,
#      'LineTaxCode': None,
#      'XeroSalesAccount': 'Sales',
#      'SerialNumbers': None,
#      'BatchNumbers': None,
#      'Guid': '2035d857-c74b-45e8-97d9-f221b9851ec9',
#      'LastModifiedOn': '/Date(1564409435373)/'}],
#    'OrderNumber': 'SO-00005602',
#    'OrderDate': '/Date(1564441200000)/',
#    'RequiredDate': '/Date(1564441200000)/',
#    'CompletedDate': None,
#    'OrderStatus': 'Parked',
#    'Customer': {'CustomerCode': 'Hill Contracting',
#     'CustomerName': 'Hill Contracting',
#     'CurrencyId': 151,
#     'Guid': '79ecff0d-1bc8-4fae-82fd-9b4b3a1a86da',
#     'LastModifiedOn': '/Date(1561398980651)/'},
#    'CustomerRef': 'smith weathered',
#    'Comments': None,
#    'Warehouse': {'WarehouseCode': 'IW',
#     'WarehouseName': 'Installers Warehouse',
#     'IsDefault': True,
#     'StreetNo': 'Installers Warehouse, Inc.',
#     'AddressLine1': '1677C Lyell Ave.',
#     'AddressLine2': None,
#     'Suburb': None,
#     'City': 'Rochester',
#     'Region': 'NY',
#     'Country': None,
#     'PostCode': '14606',
#     'PhoneNumber': None,
#     'FaxNumber': None,
#     'MobileNumber': None,
#     'DDINumber': None,
#     'ContactName': None,
#     'Obsolete': False,
#     'Guid': 'f8aedb90-413a-4628-b1e4-80b609abe455',
#     'LastModifiedOn': '/Date(1555075989301)/'},
#    'ReceivedDate': None,
#    'DeliveryName': None,
#    'DeliveryStreetAddress': 'Pick up',
#    'DeliveryStreetAddress2': None,
#    'DeliverySuburb': None,
#    'DeliveryCity': None,
#    'DeliveryRegion': None,
#    'DeliveryCountry': None,
#    'DeliveryPostCode': None,
#    'Currency': {'CurrencyCode': 'USD',
#     'Description': 'United States of America, Dollars',
#     'Guid': '8e4702ad-594b-4e80-9e0c-bfe77b8aa9f6',
#     'LastModifiedOn': '/Date(1513109457456)/'},
#    'ExchangeRate': 1.0,
#    'DiscountRate': 0.0,
#    'Tax': {'TaxCode': 'Steuben County',
#     'Description': None,
#     'TaxRate': 0.08,
#     'CanApplyToExpenses': False,
#     'CanApplyToRevenue': False,
#     'Obsolete': False,
#     'Guid': '00000000-0000-0000-0000-000000000000',
#     'LastModifiedOn': None},
#    'TaxRate': 0.08,
#    'XeroTaxCode': 'Steuben County',
#    'SubTotal': 2738.09,
#    'TaxTotal': 219.05,
#    'Total': 2957.14,
#    'TotalVolume': 0.0,
#    'TotalWeight': 0.0,
#    'BCSubTotal': 2738.09,
#    'BCTaxTotal': 219.05,
#    'BCTotal': 2957.14,
#    'PaymentDueDate': '/Date(1564395035263)/',
#    'AllocateProduct': True,
#    'SalesOrderGroup': None,
#    'DeliveryMethod': None,
#    'SalesPerson': None,
#    'SendAccountingJournalOnly': False,
#    'SourceId': None,
#    'CreatedBy': 'dave@iwhardwood.com',
#    'CreatedOn': '/Date(1564408903634)/',
#    'LastModifiedBy': 'dave@iwhardwood.com',
#    'Guid': 'adad6154-f037-4c04-83ea-14c5c28a08ea',
#    'LastModifiedOn': '/Date(1564409435388)/'},
#   {'SalesOrderLines': [{'LineNumber': 1,
#      'LineType': None,
#      'Product': {'Guid': 'cefc9904-2d31-4d84-bd82-d6df1b9d56dc',
#       'ProductCode': 'MetGen600Wea',
#       'ProductDescription': 'Genesis 600 Weathered'},
#      'DueDate': '/Date(1564409065153)/',
#      'OrderQuantity': 297.0,
#      'UnitPrice': 2.99,
#      'DiscountRate': 0.0,
#      'LineTotal': 888.03,
#      'Volume': None,
#      'Weight': None,
#      'Comments': '',
#      'AverageLandedPriceAtTimeOfSale': 1.87430088766452,
#      'TaxRate': 0.08,
#      'LineTax': 71.04,
#      'XeroTaxCode': 'Steuben County',
#      'BCUnitPrice': 2.99,
#      'BCLineTotal': 888.03,
#      'BCLineTax': 71.04,
#      'LineTaxCode': None,
#      'XeroSalesAccount': 'Sales',
#      'SerialNumbers': None,
#      'BatchNumbers': None,
#      'Guid': 'ced68d20-cc76-486b-a47b-f4a3b9f7484b',
#      'LastModifiedOn': '/Date(1564409406724)/'}],
#    'OrderNumber': 'SO-00005603',
#    'OrderDate': '/Date(1564441200000)/',
#    'RequiredDate': '/Date(1564441200000)/',
#    'CompletedDate': None,
#    'OrderStatus': 'Parked',
#    'Customer': {'CustomerCode': 'Hill Contracting',
#     'CustomerName': 'Hill Contracting',
#     'CurrencyId': 151,
#     'Guid': '79ecff0d-1bc8-4fae-82fd-9b4b3a1a86da',
#     'LastModifiedOn': '/Date(1561398980651)/'},
#    'CustomerRef': 'hampshire',
#    'Comments': None,
#    'Warehouse': {'WarehouseCode': 'IW',
#     'WarehouseName': 'Installers Warehouse',
#     'IsDefault': True,
#     'StreetNo': 'Installers Warehouse, Inc.',
#     'AddressLine1': '1677C Lyell Ave.',
#     'AddressLine2': None,
#     'Suburb': None,
#     'City': 'Rochester',
#     'Region': 'NY',
#     'Country': None,
#     'PostCode': '14606',
#     'PhoneNumber': None,
#     'FaxNumber': None,
#     'MobileNumber': None,
#     'DDINumber': None,
#     'ContactName': None,
#     'Obsolete': False,
#     'Guid': 'f8aedb90-413a-4628-b1e4-80b609abe455',
#     'LastModifiedOn': '/Date(1555075989301)/'},
#    'ReceivedDate': None,
#    'DeliveryName': None,
#    'DeliveryStreetAddress': None,
#    'DeliveryStreetAddress2': None,
#    'DeliverySuburb': None,
#    'DeliveryCity': None,
#    'DeliveryRegion': None,
#    'DeliveryCountry': None,
#    'DeliveryPostCode': None,
#    'Currency': {'CurrencyCode': 'USD',
#     'Description': 'United States of America, Dollars',
#     'Guid': '8e4702ad-594b-4e80-9e0c-bfe77b8aa9f6',
#     'LastModifiedOn': '/Date(1513109457456)/'},
#    'ExchangeRate': 1.0,
#    'DiscountRate': 0.0,
#    'Tax': {'TaxCode': 'Steuben County',
#     'Description': None,
#     'TaxRate': 0.08,
#     'CanApplyToExpenses': False,
#     'CanApplyToRevenue': False,
#     'Obsolete': False,
#     'Guid': '00000000-0000-0000-0000-000000000000',
#     'LastModifiedOn': None},
#    'TaxRate': 0.08,
#    'XeroTaxCode': 'Steuben County',
#    'SubTotal': 888.03,
#    'TaxTotal': 71.04,
#    'Total': 959.07,
#    'TotalVolume': 0.0,
#    'TotalWeight': 0.0,
#    'BCSubTotal': 888.03,
#    'BCTaxTotal': 71.04,
#    'BCTotal': 959.07,
#    'PaymentDueDate': '/Date(1564395006693)/',
#    'AllocateProduct': True,
#    'SalesOrderGroup': None,
#    'DeliveryMethod': None,
#    'SalesPerson': None,
#    'SendAccountingJournalOnly': False,
#    'SourceId': None,
#    'CreatedBy': 'dave@iwhardwood.com',
#    'CreatedOn': '/Date(1564409065168)/',
#    'LastModifiedBy': 'dave@iwhardwood.com',
#    'Guid': 'dbe7386d-fc40-43f2-a5ac-05e20642a02e',
#    'LastModifiedOn': '/Date(1564409406740)/'},
#   {'SalesOrderLines': [{'LineNumber': 1,
#      'LineType': None,
#      'Product': {'Guid': '489ced97-83b3-4944-9717-5b6c439f83e5',
#       'ProductCode': 'MetGen600Tan',
#       'ProductDescription': 'Genesis 600 Tannin'},
#      'DueDate': '/Date(1564409224560)/',
#      'OrderQuantity': 470.25,
#      'UnitPrice': 2.99,
#      'DiscountRate': 0.0,
#      'LineTotal': 1406.05,
#      'Volume': None,
#      'Weight': None,
#      'Comments': '',
#      'AverageLandedPriceAtTimeOfSale': 1.8000202020202,
#      'TaxRate': 0.08,
#      'LineTax': 112.48,
#      'XeroTaxCode': 'Steuben County',
#      'BCUnitPrice': 2.99,
#      'BCLineTotal': 1406.05,
#      'BCLineTax': 112.48,
#      'LineTaxCode': None,
#      'XeroSalesAccount': 'Sales',
#      'SerialNumbers': None,
#      'BatchNumbers': None,
#      'Guid': '6d003914-6741-422a-8527-0c52f9fbe6f1',
#      'LastModifiedOn': '/Date(1564409307100)/'}],
#    'OrderNumber': 'SO-00005604',
#    'OrderDate': '/Date(1564441200000)/',
#    'RequiredDate': '/Date(1564441200000)/',
#    'CompletedDate': None,
#    'OrderStatus': 'Parked',
#    'Customer': {'CustomerCode': 'Hill Contracting',
#     'CustomerName': 'Hill Contracting',
#     'CurrencyId': 151,
#     'Guid': '79ecff0d-1bc8-4fae-82fd-9b4b3a1a86da',
#     'LastModifiedOn': '/Date(1561398980651)/'},
#    'CustomerRef': 'faulkerner',
#    'Comments': None,
#    'Warehouse': {'WarehouseCode': 'IW',
#     'WarehouseName': 'Installers Warehouse',
#     'IsDefault': True,
#     'StreetNo': 'Installers Warehouse, Inc.',
#     'AddressLine1': '1677C Lyell Ave.',
#     'AddressLine2': None,
#     'Suburb': None,
#     'City': 'Rochester',
#     'Region': 'NY',
#     'Country': None,
#     'PostCode': '14606',
#     'PhoneNumber': None,
#     'FaxNumber': None,
#     'MobileNumber': None,
#     'DDINumber': None,
#     'ContactName': None,
#     'Obsolete': False,
#     'Guid': 'f8aedb90-413a-4628-b1e4-80b609abe455',
#     'LastModifiedOn': '/Date(1555075989301)/'},
#    'ReceivedDate': None,
#    'DeliveryName': None,
#    'DeliveryStreetAddress': None,
#    'DeliveryStreetAddress2': None,
#    'DeliverySuburb': None,
#    'DeliveryCity': None,
#    'DeliveryRegion': None,
#    'DeliveryCountry': None,
#    'DeliveryPostCode': None,
#    'Currency': {'CurrencyCode': 'USD',
#     'Description': 'United States of America, Dollars',
#     'Guid': '8e4702ad-594b-4e80-9e0c-bfe77b8aa9f6',
#     'LastModifiedOn': '/Date(1513109457456)/'},
#    'ExchangeRate': 1.0,
#    'DiscountRate': 0.0,
#    'Tax': {'TaxCode': 'Steuben County',
#     'Description': None,
#     'TaxRate': 0.08,
#     'CanApplyToExpenses': False,
#     'CanApplyToRevenue': False,
#     'Obsolete': False,
#     'Guid': '00000000-0000-0000-0000-000000000000',
#     'LastModifiedOn': None},
#    'TaxRate': 0.08,
#    'XeroTaxCode': 'Steuben County',
#    'SubTotal': 1406.05,
#    'TaxTotal': 112.48,
#    'Total': 1518.53,
#    'TotalVolume': 0.0,
#    'TotalWeight': 0.0,
#    'BCSubTotal': 1406.05,
#    'BCTaxTotal': 112.48,
#    'BCTotal': 1518.53,
#    'PaymentDueDate': '/Date(1564394907084)/',
#    'AllocateProduct': True,
#    'SalesOrderGroup': None,
#    'DeliveryMethod': None,
#    'SalesPerson': None,
#    'SendAccountingJournalOnly': False,
#    'SourceId': None,
#    'CreatedBy': 'dave@iwhardwood.com',
#    'CreatedOn': '/Date(1564409224592)/',
#    'LastModifiedBy': 'dave@iwhardwood.com',
#    'Guid': '46ae9ab5-d09b-44b5-a167-e5b52c7e4986',
#    'LastModifiedOn': '/Date(1564409307115)/'},
#   {'SalesOrderLines': [{'LineNumber': 1,
#      'LineType': None,
#      'Product': {'Guid': 'eb65ec1e-0c56-4e09-96fd-43a77b7ef8d9',
#       'ProductCode': 'CumRed3Sel',
#       'ProductDescription': "Red Oak Select & Better 3.25'"},
#      'DueDate': '/Date(1563823844926)/',
#      'OrderQuantity': 1729.0,
#      'UnitPrice': 3.59,
#      'DiscountRate': 0.0,
#      'LineTotal': 6207.11,
#      'Volume': None,
#      'Weight': None,
#      'Comments': '',
#      'AverageLandedPriceAtTimeOfSale': 2.65570643990156,
#      'TaxRate': 0.08,
#      'LineTax': 496.57,
#      'XeroTaxCode': 'Chautauqua County',
#      'BCUnitPrice': 3.59,
#      'BCLineTotal': 6207.11,
#      'BCLineTax': 496.57,
#      'LineTaxCode': None,
#      'XeroSalesAccount': 'Sales',
#      'SerialNumbers': None,
#      'BatchNumbers': None,
#      'Guid': '3460fb18-17c7-4814-9446-aa81c8d07c3a',
#      'LastModifiedOn': '/Date(1563824618027)/'},
#     {'LineNumber': 2,
#      'LineType': None,
#      'Product': {'Guid': '870f5f20-6408-4ff3-a944-45c4744ceb6b',
#       'ProductCode': 'Delivery',
#       'ProductDescription': 'Delivery Fee'},
#      'DueDate': '/Date(1563823844926)/',
#      'OrderQuantity': 1.0,
#      'UnitPrice': 85.0,
#      'DiscountRate': 0.0,
#      'LineTotal': 85.0,
#      'Volume': None,
#      'Weight': None,
#      'Comments': '',
#      'AverageLandedPriceAtTimeOfSale': 0.0,
#      'TaxRate': 0.08,
#      'LineTax': 6.8,
#      'XeroTaxCode': 'Chautauqua County',
#      'BCUnitPrice': 85.0,
#      'BCLineTotal': 85.0,
#      'BCLineTax': 6.8,
#      'LineTaxCode': None,
#      'XeroSalesAccount': 'Sales',
#      'SerialNumbers': None,
#      'BatchNumbers': None,
#      'Guid': '360a8a3e-e95a-475e-a865-2bec623eea82',
#      'LastModifiedOn': '/Date(1563824618043)/'}],
#    'OrderNumber': 'SO-00005539',
#    'OrderDate': '/Date(1563836400000)/',
#    'RequiredDate': '/Date(1567378800000)/',
#    'CompletedDate': None,
#    'OrderStatus': 'Parked',
#    'Customer': {'CustomerCode': 'GALLIVAN, EDWARD',
#     'CustomerName': 'GALLIVAN, EDWARD',
#     'CurrencyId': 151,
#     'Guid': '2710d6c8-72aa-40e3-b883-5e647542d447',
#     'LastModifiedOn': '/Date(1561398979837)/'},
#    'CustomerRef': None,
#    'Comments': None,
#    'Warehouse': {'WarehouseCode': 'IW',
#     'WarehouseName': 'Installers Warehouse',
#     'IsDefault': True,
#     'StreetNo': 'Installers Warehouse, Inc.',
#     'AddressLine1': '1677C Lyell Ave.',
#     'AddressLine2': None,
#     'Suburb': None,
#     'City': 'Rochester',
#     'Region': 'NY',
#     'Country': None,
#     'PostCode': '14606',
#     'PhoneNumber': None,
#     'FaxNumber': None,
#     'MobileNumber': None,
#     'DDINumber': None,
#     'ContactName': None,
#     'Obsolete': False,
#     'Guid': 'f8aedb90-413a-4628-b1e4-80b609abe455',
#     'LastModifiedOn': '/Date(1555075989301)/'},
#    'ReceivedDate': None,
#    'DeliveryName': 'Wallenhorst 716-673-6562',
#    'DeliveryStreetAddress': '7470 Lakeshore drive East',
#    'DeliveryStreetAddress2': None,
#    'DeliverySuburb': None,
#    'DeliveryCity': 'Dunkirk',
#    'DeliveryRegion': None,
#    'DeliveryCountry': None,
#    'DeliveryPostCode': None,
#    'Currency': {'CurrencyCode': 'USD',
#     'Description': 'United States of America, Dollars',
#     'Guid': '8e4702ad-594b-4e80-9e0c-bfe77b8aa9f6',
#     'LastModifiedOn': '/Date(1513109457456)/'},
#    'ExchangeRate': 1.0,
#    'DiscountRate': 0.0,
#    'Tax': {'TaxCode': 'Chautauqua County',
#     'Description': None,
#     'TaxRate': 0.08,
#     'CanApplyToExpenses': False,
#     'CanApplyToRevenue': False,
#     'Obsolete': False,
#     'Guid': '00000000-0000-0000-0000-000000000000',
#     'LastModifiedOn': None},
#    'TaxRate': 0.08,
#    'XeroTaxCode': 'Chautauqua County',
#    'SubTotal': 6292.11,
#    'TaxTotal': 503.37,
#    'Total': 6795.48,
#    'TotalVolume': 0.0,
#    'TotalWeight': 0.0,
#    'BCSubTotal': 6292.11,
#    'BCTaxTotal': 503.37,
#    'BCTotal': 6795.48,
#    'PaymentDueDate': '/Date(1566402217980)/',
#    'AllocateProduct': True,
#    'SalesOrderGroup': None,
#    'DeliveryMethod': None,
#    'SalesPerson': None,
#    'SendAccountingJournalOnly': False,
#    'SourceId': None,
#    'CreatedBy': 'dave@iwhardwood.com',
#    'CreatedOn': '/Date(1563823845192)/',
#    'LastModifiedBy': 'dave@iwhardwood.com',
#    'Guid': 'ba85c27a-47b4-443c-9ca0-220143e8c65b',
#    'LastModifiedOn': '/Date(1563824618043)/'},
#   {'SalesOrderLines': [{'LineNumber': 1,
#      'LineType': None,
#      'Product': {'Guid': '34c15709-c0f5-4267-a233-2179617513ff',
#       'ProductCode': 'WicAshCan4Cop',
#       'ProductDescription': "Can+ Ash 4.25' Copper"},
#      'DueDate': '/Date(1563545191593)/',
#      'OrderQuantity': 400.0,
#      'UnitPrice': 3.99,
#      'DiscountRate': 0.0,
#      'LineTotal': 1596.0,
#      'Volume': None,
#      'Weight': None,
#      'Comments': '',
#      'AverageLandedPriceAtTimeOfSale': 0.0,
#      'TaxRate': 0.0,
#      'LineTax': 0.0,
#      'XeroTaxCode': 'NONE',
#      'BCUnitPrice': 3.99,
#      'BCLineTotal': 1596.0,
#      'BCLineTax': 0.0,
#      'LineTaxCode': None,
#      'XeroSalesAccount': 'Sales',
#      'SerialNumbers': None,
#      'BatchNumbers': None,
#      'Guid': 'a7a7b578-391a-43cf-afdc-09d64d784c52',
#      'LastModifiedOn': '/Date(1563795702499)/'},
#     {'LineNumber': 2,
#      'LineType': None,
#      'Product': {'Guid': '8b01d1cd-30f1-406c-8b9f-99f34c33189f',
#       'ProductCode': 'WicTriAshRedCop',
#       'ProductDescription': "Ash Reducer 84' Copper/Gunstock"},
#      'DueDate': '/Date(1563545191593)/',
#      'OrderQuantity': 1.0,
#      'UnitPrice': 44.29,
#      'DiscountRate': 0.0,
#      'LineTotal': 44.29,
#      'Volume': None,
#      'Weight': None,
#      'Comments': '',
#      'AverageLandedPriceAtTimeOfSale': 0.0,
#      'TaxRate': 0.0,
#      'LineTax': 0.0,
#      'XeroTaxCode': 'NONE',
#      'BCUnitPrice': 44.29,
#      'BCLineTotal': 44.29,
#      'BCLineTax': 0.0,
#      'LineTaxCode': None,
#      'XeroSalesAccount': 'Sales',
#      'SerialNumbers': None,
#      'BatchNumbers': None,
#      'Guid': 'ca099c2c-268a-4b19-9d9f-65a1a17919a4',
#      'LastModifiedOn': '/Date(1563795702515)/'}],
#    'OrderNumber': 'SO-00005516',
#    'OrderDate': '/Date(1563577200000)/',
#    'RequiredDate': '/Date(1563577200000)/',
#    'CompletedDate': None,
#    'OrderStatus': 'Parked',
#    'Customer': {'CustomerCode': 'CUSTOM CARPET CENTERS',
#     'CustomerName': 'CUSTOM CARPET CENTERS',
#     'CurrencyId': 151,
#     'Guid': 'd0af610b-efcd-4bee-8a55-4a135168ba07',
#     'LastModifiedOn': '/Date(1561398977115)/'},
#    'CustomerRef': 'V070503 Engl',
#    'Comments': None,
#    'Warehouse': {'WarehouseCode': 'IW',
#     'WarehouseName': 'Installers Warehouse',
#     'IsDefault': True,
#     'StreetNo': 'Installers Warehouse, Inc.',
#     'AddressLine1': '1677C Lyell Ave.',
#     'AddressLine2': None,
#     'Suburb': None,
#     'City': 'Rochester',
#     'Region': 'NY',
#     'Country': None,
#     'PostCode': '14606',
#     'PhoneNumber': None,
#     'FaxNumber': None,
#     'MobileNumber': None,
#     'DDINumber': None,
#     'ContactName': None,
#     'Obsolete': False,
#     'Guid': 'f8aedb90-413a-4628-b1e4-80b609abe455',
#     'LastModifiedOn': '/Date(1555075989301)/'},
#    'ReceivedDate': None,
#    'DeliveryName': None,
#    'DeliveryStreetAddress': None,
#    'DeliveryStreetAddress2': None,
#    'DeliverySuburb': None,
#    'DeliveryCity': None,
#    'DeliveryRegion': None,
#    'DeliveryCountry': None,
#    'DeliveryPostCode': None,
#    'Currency': {'CurrencyCode': 'USD',
#     'Description': 'United States of America, Dollars',
#     'Guid': '8e4702ad-594b-4e80-9e0c-bfe77b8aa9f6',
#     'LastModifiedOn': '/Date(1513109457456)/'},
#    'ExchangeRate': 1.0,
#    'DiscountRate': 0.0,
#    'Tax': {'TaxCode': 'NONE',
#     'Description': None,
#     'TaxRate': 0.0,
#     'CanApplyToExpenses': False,
#     'CanApplyToRevenue': False,
#     'Obsolete': False,
#     'Guid': '00000000-0000-0000-0000-000000000000',
#     'LastModifiedOn': None},
#    'TaxRate': 0.0,
#    'XeroTaxCode': 'NONE',
#    'SubTotal': 1640.29,
#    'TaxTotal': 0.0,
#    'Total': 1640.29,
#    'TotalVolume': 0.0,
#    'TotalWeight': 0.0,
#    'BCSubTotal': 1640.29,
#    'BCTaxTotal': 0.0,
#    'BCTotal': 1640.29,
#    'PaymentDueDate': '/Date(1567669302484)/',
#    'AllocateProduct': True,
#    'SalesOrderGroup': None,
#    'DeliveryMethod': None,
#    'SalesPerson': None,
#    'SendAccountingJournalOnly': False,
#    'SourceId': None,
#    'CreatedBy': 'dave@iwhardwood.com',
#    'CreatedOn': '/Date(1563545191641)/',
#    'LastModifiedBy': 'dave@iwhardwood.com',
#    'Guid': '71846e45-bada-4232-b9a2-99f65999c002',
#    'LastModifiedOn': '/Date(1563795702515)/'},
#   {'SalesOrderLines': [{'LineNumber': 1,
#      'LineType': None,
#      'Product': {'Guid': 'eb66d8b6-428c-4983-a351-2e9fc0fd6047',
#       'ProductCode': 'WicWilAsh4Haz',
#       'ProductDescription': 'Wild West Ash 4.25 Haze'},
#      'DueDate': '/Date(1563377553353)/',
#      'OrderQuantity': 1140.0,
#      'UnitPrice': 4.39,
#      'DiscountRate': 0.0,
#      'LineTotal': 5004.6,
#      'Volume': None,
#      'Weight': None,
#      'Comments': '',
#      'AverageLandedPriceAtTimeOfSale': 3.473,
#      'TaxRate': 0.0,
#      'LineTax': 0.0,
#      'XeroTaxCode': 'NONE',
#      'BCUnitPrice': 4.39,
#      'BCLineTotal': 5004.6,
#      'BCLineTax': 0.0,
#      'LineTaxCode': None,
#      'XeroSalesAccount': 'Sales',
#      'SerialNumbers': None,
#      'BatchNumbers': None,
#      'Guid': '3e0e98d1-2c61-4890-b214-ff7575a80ca7',
#      'LastModifiedOn': '/Date(1563382994897)/'},
#     {'LineNumber': 2,
#      'LineType': None,
#      'Product': {'Guid': '8da1abb5-3d75-4766-a778-b5f660b603ce',
#       'ProductCode': 'ForUndAQU',
#       'ProductDescription': 'AQUABAR'},
#      'DueDate': '/Date(1563377553353)/',
#      'OrderQuantity': 3.0,
#      'UnitPrice': 17.0,
#      'DiscountRate': 0.0,
#      'LineTotal': 51.0,
#      'Volume': None,
#      'Weight': None,
#      'Comments': '',
#      'AverageLandedPriceAtTimeOfSale': 14.93943555555556,
#      'TaxRate': 0.0,
#      'LineTax': 0.0,
#      'XeroTaxCode': 'NONE',
#      'BCUnitPrice': 17.0,
#      'BCLineTotal': 51.0,
#      'BCLineTax': 0.0,
#      'LineTaxCode': None,
#      'XeroSalesAccount': 'Sales',
#      'SerialNumbers': None,
#      'BatchNumbers': None,
#      'Guid': '07ad135d-1bfa-4827-85b4-af03d66dbb73',
#      'LastModifiedOn': '/Date(1563382994913)/'},
#     {'LineNumber': 3,
#      'LineType': None,
#      'Product': {'Guid': 'c2437047-c9d8-4c4c-83a4-7252b394b686',
#       'ProductCode': 'WicWilTriAshNosHaz',
#       'ProductDescription': 'Wild West Ash Nosing 84" Haze'},
#      'DueDate': '/Date(1563404400000)/',
#      'OrderQuantity': 5.0,
#      'UnitPrice': 82.0899,
#      'DiscountRate': 0.0,
#      'LineTotal': 410.45,
#      'Volume': None,
#      'Weight': None,
#      'Comments': '',
#      'AverageLandedPriceAtTimeOfSale': 0.0,
#      'TaxRate': 0.0,
#      'LineTax': 0.0,
#      'XeroTaxCode': 'NONE',
#      'BCUnitPrice': 82.0899,
#      'BCLineTotal': 410.45,
#      'BCLineTax': 0.0,
#      'LineTaxCode': None,
#      'XeroSalesAccount': 'Sales',
#      'SerialNumbers': None,
#      'BatchNumbers': None,
#      'Guid': '94f081d3-bbe2-4f91-aa31-45c44490fd30',
#      'LastModifiedOn': '/Date(1563382994913)/'}],
#    'OrderNumber': 'SO-00005478',
#    'OrderDate': '/Date(1563404400000)/',
#    'RequiredDate': '/Date(1563404400000)/',
#    'CompletedDate': None,
#    'OrderStatus': 'Parked',
#    'Customer': {'CustomerCode': 'Nickel City Hardwood, LLC',
#     'CustomerName': 'Nickel City Hardwood, LLC',
#     'CurrencyId': 151,
#     'Guid': 'bccb4f4f-dfc5-4e01-bbc1-c9c9ae5a940f',
#     'LastModifiedOn': '/Date(1561563726426)/'},
#    'CustomerRef': 'PO 640 WW Ash Haze',
#    'Comments': None,
#    'Warehouse': {'WarehouseCode': 'IW',
#     'WarehouseName': 'Installers Warehouse',
#     'IsDefault': True,
#     'StreetNo': 'Installers Warehouse, Inc.',
#     'AddressLine1': '1677C Lyell Ave.',
#     'AddressLine2': None,
#     'Suburb': None,
#     'City': 'Rochester',
#     'Region': 'NY',
#     'Country': None,
#     'PostCode': '14606',
#     'PhoneNumber': None,
#     'FaxNumber': None,
#     'MobileNumber': None,
#     'DDINumber': None,
#     'ContactName': None,
#     'Obsolete': False,
#     'Guid': 'f8aedb90-413a-4628-b1e4-80b609abe455',
#     'LastModifiedOn': '/Date(1555075989301)/'},
#    'ReceivedDate': None,
#    'DeliveryName': None,
#    'DeliveryStreetAddress': '6 Walnut Creek ',
#    'DeliveryStreetAddress2': None,
#    'DeliverySuburb': None,
#    'DeliveryCity': 'Lancaster',
#    'DeliveryRegion': None,
#    'DeliveryCountry': None,
#    'DeliveryPostCode': None,
#    'Currency': {'CurrencyCode': 'USD',
#     'Description': 'United States of America, Dollars',
#     'Guid': '8e4702ad-594b-4e80-9e0c-bfe77b8aa9f6',
#     'LastModifiedOn': '/Date(1513109457456)/'},
#    'ExchangeRate': 1.0,
#    'DiscountRate': 0.0,
#    'Tax': {'TaxCode': 'NONE',
#     'Description': None,
#     'TaxRate': 0.0,
#     'CanApplyToExpenses': False,
#     'CanApplyToRevenue': False,
#     'Obsolete': False,
#     'Guid': '00000000-0000-0000-0000-000000000000',
#     'LastModifiedOn': None},
#    'TaxRate': 0.0,
#    'XeroTaxCode': 'NONE',
#    'SubTotal': 5466.05,
#    'TaxTotal': 0.0,
#    'Total': 5466.05,
#    'TotalVolume': 0.0,
#    'TotalWeight': 0.0,
#    'BCSubTotal': 5466.05,
#    'BCTaxTotal': 0.0,
#    'BCTotal': 5466.05,
#    'PaymentDueDate': '/Date(1565960594881)/',
#    'AllocateProduct': True,
#    'SalesOrderGroup': None,
#    'DeliveryMethod': None,
#    'SalesPerson': None,
#    'SendAccountingJournalOnly': False,
#    'SourceId': None,
#    'CreatedBy': 'dave@iwhardwood.com',
#    'CreatedOn': '/Date(1563377553368)/',
#    'LastModifiedBy': 'dave@iwhardwood.com',
#    'Guid': 'c880afaf-66a6-441a-9302-3a1c8b3b5829',
#    'LastModifiedOn': '/Date(1563382994913)/'},
#   {'SalesOrderLines': [{'LineNumber': 1,
#      'LineType': None,
#      'Product': {'Guid': 'b0fd8df9-791e-4148-99c1-32a9941bea51',
#       'ProductCode': 'MetGen600Ash',
#       'ProductDescription': 'Genesis 600 Ash'},
#      'DueDate': '/Date(1563288928860)/',
#      'OrderQuantity': 668.25,
#      'UnitPrice': 2.99,
#      'DiscountRate': 0.0,
#      'LineTotal': 1998.07,
#      'Volume': None,
#      'Weight': None,
#      'Comments': None,
#      'AverageLandedPriceAtTimeOfSale': 1.81228896741264,
#      'TaxRate': 0.08,
#      'LineTax': 159.85,
#      'XeroTaxCode': 'Steuben County',
#      'BCUnitPrice': 2.99,
#      'BCLineTotal': 1998.07,
#      'BCLineTax': 159.85,
#      'LineTaxCode': None,
#      'XeroSalesAccount': 'Sales',
#      'SerialNumbers': None,
#      'BatchNumbers': None,
#      'Guid': '9ec68f74-1983-4fe7-bc51-66887973d7df',
#      'LastModifiedOn': '/Date(1563288945880)/'}],
#    'OrderNumber': 'SO-00005463',
#    'OrderDate': '/Date(1563318000000)/',
#    'RequiredDate': '/Date(1563318000000)/',
#    'CompletedDate': None,
#    'OrderStatus': 'Parked',
#    'Customer': {'CustomerCode': 'Hill Contracting',
#     'CustomerName': 'Hill Contracting',
#     'CurrencyId': 151,
#     'Guid': '79ecff0d-1bc8-4fae-82fd-9b4b3a1a86da',
#     'LastModifiedOn': '/Date(1561398980651)/'},
#    'CustomerRef': 'ash vinyl',
#    'Comments': None,
#    'Warehouse': {'WarehouseCode': 'IW',
#     'WarehouseName': 'Installers Warehouse',
#     'IsDefault': True,
#     'StreetNo': 'Installers Warehouse, Inc.',
#     'AddressLine1': '1677C Lyell Ave.',
#     'AddressLine2': None,
#     'Suburb': None,
#     'City': 'Rochester',
#     'Region': 'NY',
#     'Country': None,
#     'PostCode': '14606',
#     'PhoneNumber': None,
#     'FaxNumber': None,
#     'MobileNumber': None,
#     'DDINumber': None,
#     'ContactName': None,
#     'Obsolete': False,
#     'Guid': 'f8aedb90-413a-4628-b1e4-80b609abe455',
#     'LastModifiedOn': '/Date(1555075989301)/'},
#    'ReceivedDate': None,
#    'DeliveryName': None,
#    'DeliveryStreetAddress': None,
#    'DeliveryStreetAddress2': None,
#    'DeliverySuburb': None,
#    'DeliveryCity': None,
#    'DeliveryRegion': None,
#    'DeliveryCountry': None,
#    'DeliveryPostCode': None,
#    'Currency': {'CurrencyCode': 'USD',
#     'Description': 'United States of America, Dollars',
#     'Guid': '8e4702ad-594b-4e80-9e0c-bfe77b8aa9f6',
#     'LastModifiedOn': '/Date(1513109457456)/'},
#    'ExchangeRate': 1.0,
#    'DiscountRate': 0.0,
#    'Tax': {'TaxCode': 'Steuben County',
#     'Description': None,
#     'TaxRate': 0.08,
#     'CanApplyToExpenses': False,
#     'CanApplyToRevenue': False,
#     'Obsolete': False,
#     'Guid': '00000000-0000-0000-0000-000000000000',
#     'LastModifiedOn': None},
#    'TaxRate': 0.08,
#    'XeroTaxCode': 'Steuben County',
#    'SubTotal': 1998.07,
#    'TaxTotal': 159.85,
#    'Total': 2157.92,
#    'TotalVolume': 0.0,
#    'TotalWeight': 0.0,
#    'BCSubTotal': 1998.07,
#    'BCTaxTotal': 159.85,
#    'BCTotal': 2157.92,
#    'PaymentDueDate': '/Date(1563274545865)/',
#    'AllocateProduct': True,
#    'SalesOrderGroup': None,
#    'DeliveryMethod': None,
#    'SalesPerson': None,
#    'SendAccountingJournalOnly': False,
#    'SourceId': None,
#    'CreatedBy': 'jon@iwhardwood.com',
#    'CreatedOn': '/Date(1563288928875)/',
#    'LastModifiedBy': 'jon@iwhardwood.com',
#    'Guid': '018a9aa3-3531-48f6-a105-246039d58602',
#    'LastModifiedOn': '/Date(1563288945896)/'},
#   {'SalesOrderLines': [{'LineNumber': 1,
#      'LineType': None,
#      'Product': {'Guid': '14e43757-fe17-43ae-8944-086063a1ccb5',
#       'ProductCode': 'WicRedCan4WheSat',
#       'ProductDescription': "Can+ Red Oak 4.25' Wheat Satin"},
#      'DueDate': '/Date(1563216838993)/',
#      'OrderQuantity': 2060.0,
#      'UnitPrice': 5.49,
#      'DiscountRate': 0.0,
#      'LineTotal': 11309.4,
#      'Volume': None,
#      'Weight': None,
#      'Comments': '',
#      'AverageLandedPriceAtTimeOfSale': 3.707,
#      'TaxRate': 0.075,
#      'LineTax': 848.21,
#      'XeroTaxCode': 'Ontario County',
#      'BCUnitPrice': 5.49,
#      'BCLineTotal': 11309.4,
#      'BCLineTax': 848.21,
#      'LineTaxCode': None,
#      'XeroSalesAccount': 'Sales',
#      'SerialNumbers': None,
#      'BatchNumbers': None,
#      'Guid': 'adb15111-4d31-4599-a38d-1422d232296d',
#      'LastModifiedOn': '/Date(1563217467835)/'},
#     {'LineNumber': 2,
#      'LineType': None,
#      'Product': {'Guid': '870f5f20-6408-4ff3-a944-45c4744ceb6b',
#       'ProductCode': 'Delivery',
#       'ProductDescription': 'Delivery Fee'},
#      'DueDate': '/Date(1563216838993)/',
#      'OrderQuantity': 1.0,
#      'UnitPrice': 115.0,
#      'DiscountRate': 0.0,
#      'LineTotal': 115.0,
#      'Volume': None,
#      'Weight': None,
#      'Comments': '',
#      'AverageLandedPriceAtTimeOfSale': 0.0,
#      'TaxRate': 0.075,
#      'LineTax': 8.63,
#      'XeroTaxCode': 'Ontario County',
#      'BCUnitPrice': 115.0,
#      'BCLineTotal': 115.0,
#      'BCLineTax': 8.63,
#      'LineTaxCode': None,
#      'XeroSalesAccount': 'Sales',
#      'SerialNumbers': None,
#      'BatchNumbers': None,
#      'Guid': '70ceff49-7b6e-4ca3-a9aa-cc0f75edff43',
#      'LastModifiedOn': '/Date(1563217467835)/'}],
#    'OrderNumber': 'SO-00005450',
#    'OrderDate': '/Date(1563231600000)/',
#    'RequiredDate': '/Date(1569279600000)/',
#    'CompletedDate': None,
#    'OrderStatus': 'Parked',
#    'Customer': {'CustomerCode': 'Chrisanntha Inc.',
#     'CustomerName': 'Chrisanntha Inc.',
#     'CurrencyId': 151,
#     'Guid': 'fd7ee20e-0586-4edf-8b7e-38b360c2a884',
#     'LastModifiedOn': '/Date(1561469707232)/'},
#    'CustomerRef': 'South Bristol Unit 13B',
#    'Comments': None,
#    'Warehouse': {'WarehouseCode': 'IW',
#     'WarehouseName': 'Installers Warehouse',
#     'IsDefault': True,
#     'StreetNo': 'Installers Warehouse, Inc.',
#     'AddressLine1': '1677C Lyell Ave.',
#     'AddressLine2': None,
#     'Suburb': None,
#     'City': 'Rochester',
#     'Region': 'NY',
#     'Country': None,
#     'PostCode': '14606',
#     'PhoneNumber': None,
#     'FaxNumber': None,
#     'MobileNumber': None,
#     'DDINumber': None,
#     'ContactName': None,
#     'Obsolete': False,
#     'Guid': 'f8aedb90-413a-4628-b1e4-80b609abe455',
#     'LastModifiedOn': '/Date(1555075989301)/'},
#    'ReceivedDate': None,
#    'DeliveryName': 'South Bristol Unit 13B',
#    'DeliveryStreetAddress': 'C11807-014',
#    'DeliveryStreetAddress2': None,
#    'DeliverySuburb': None,
#    'DeliveryCity': None,
#    'DeliveryRegion': None,
#    'DeliveryCountry': None,
#    'DeliveryPostCode': None,
#    'Currency': {'CurrencyCode': 'USD',
#     'Description': 'United States of America, Dollars',
#     'Guid': '8e4702ad-594b-4e80-9e0c-bfe77b8aa9f6',
#     'LastModifiedOn': '/Date(1513109457456)/'},
#    'ExchangeRate': 1.0,
#    'DiscountRate': 0.0,
#    'Tax': {'TaxCode': 'Ontario County',
#     'Description': None,
#     'TaxRate': 0.075,
#     'CanApplyToExpenses': False,
#     'CanApplyToRevenue': False,
#     'Obsolete': False,
#     'Guid': '00000000-0000-0000-0000-000000000000',
#     'LastModifiedOn': None},
#    'TaxRate': 0.075,
#    'XeroTaxCode': 'Ontario County',
#    'SubTotal': 11424.4,
#    'TaxTotal': 856.84,
#    'Total': 12281.24,
#    'TotalVolume': 0.0,
#    'TotalWeight': 0.0,
#    'BCSubTotal': 11424.4,
#    'BCTaxTotal': 856.84,
#    'BCTotal': 12281.24,
#    'PaymentDueDate': '/Date(1565795067788)/',
#    'AllocateProduct': True,
#    'SalesOrderGroup': None,
#    'DeliveryMethod': None,
#    'SalesPerson': None,
#    'SendAccountingJournalOnly': False,
#    'SourceId': None,
#    'CreatedBy': 'dave@iwhardwood.com',
#    'CreatedOn': '/Date(1563216839008)/',
#    'LastModifiedBy': 'dave@iwhardwood.com',
#    'Guid': 'bc01203c-83a0-4781-8e86-ea3266cbda56',
#    'LastModifiedOn': '/Date(1563217467852)/'},
#   {'SalesOrderLines': [{'LineNumber': 1,
#      'LineType': None,
#      'Product': {'Guid': '8a0cca4e-3ae4-4a1c-b1ca-3a0a5900d54f',
#       'ProductCode': 'AmeAunWO7Gra',
#       'ProductDescription': "Au Naturalle White Oak 7' Graceful Grey"},
#      'DueDate': '/Date(1562790021560)/',
#      'OrderQuantity': 1049.85,
#      'UnitPrice': 4.21,
#      'DiscountRate': 0.0,
#      'LineTotal': 4419.87,
#      'Volume': None,
#      'Weight': None,
#      'Comments': '',
#      'AverageLandedPriceAtTimeOfSale': 4.07141409811791,
#      'TaxRate': 0.0,
#      'LineTax': 0.0,
#      'XeroTaxCode': 'NONE',
#      'BCUnitPrice': 4.21,
#      'BCLineTotal': 4419.87,
#      'BCLineTax': 0.0,
#      'LineTaxCode': None,
#      'XeroSalesAccount': 'Sales',
#      'SerialNumbers': None,
#      'BatchNumbers': None,
#      'Guid': '15ba268b-cfc3-489a-8272-4cad581d7f1a',
#      'LastModifiedOn': '/Date(1562790373668)/'},
#     {'LineNumber': 2,
#      'LineType': None,
#      'Product': {'Guid': 'fc89d9f7-4c0d-4f90-9273-4d6a6424622c',
#       'ProductCode': 'AmeTriAuGraGreOlaRed',
#       'ProductDescription': 'Au Naturelle White Oak Graceful Grey Overlap Reducer 6.5 lf.'},
#      'DueDate': '/Date(1562790021560)/',
#      'OrderQuantity': 1.0,
#      'UnitPrice': 48.79,
#      'DiscountRate': 0.0,
#      'LineTotal': 48.79,
#      'Volume': None,
#      'Weight': None,
#      'Comments': '',
#      'AverageLandedPriceAtTimeOfSale': 0.0,
#      'TaxRate': 0.0,
#      'LineTax': 0.0,
# ...
#      'LastModifiedOn': '/Date(1560796043396)/'},
#     {'LineNumber': 11,
#      'LineType': None,
#      'Product': {'Guid': 'e40d0e68-f1b1-4e56-81b6-3c2a072372ea',
#       'ProductCode': 'NorEdgBlu778120',
#       'ProductDescription': "BlueFire Edger Disks 7' x 7/8' 120 GRIT"},
#      'DueDate': '/Date(1557924550340)/',
#      'OrderQuantity': 500.0,
#      'UnitPrice': 0.69,
#      'DiscountRate': 0.3333,
#      'LineTotal': 230.0,
#      'Volume': None,
#      'Weight': None,
#      'Comments': '',
#      'AverageLandedPriceAtTimeOfSale': 0.38,
#      'TaxRate': 0.08,
#      'LineTax': 18.4,
#      'XeroTaxCode': 'Niagara County',
#      'BCUnitPrice': 0.46,
#      'BCLineTotal': 230.0,
#      'BCLineTax': 18.4,
#      'LineTaxCode': None,
#      'XeroSalesAccount': 'Sales',
#      'SerialNumbers': None,
#      'BatchNumbers': None,
#      'Guid': '42e1a36c-d9dc-4f8a-87b2-1742f38a4e92',
#      'LastModifiedOn': '/Date(1560796043396)/'},
#     {'LineNumber': 12,
#      'LineType': None,
#      'Product': {'Guid': 'b8245e87-620e-4857-89b5-517d4fc990bd',
#       'ProductCode': 'NorEdgBlu77824',
#       'ProductDescription': "BlueFire Edger Disks 7' x 7/8' 24 GRIT"},
#      'DueDate': '/Date(1557924550340)/',
#      'OrderQuantity': 50.0,
#      'UnitPrice': 1.19,
#      'DiscountRate': 0.2941,
#      'LineTotal': 42.0,
#      'Volume': None,
#      'Weight': None,
#      'Comments': '',
#      'AverageLandedPriceAtTimeOfSale': 0.66,
#      'TaxRate': 0.08,
#      'LineTax': 3.36,
#      'XeroTaxCode': 'Niagara County',
#      'BCUnitPrice': 0.84,
#      'BCLineTotal': 42.0,
#      'BCLineTax': 3.36,
#      'LineTaxCode': None,
#      'XeroSalesAccount': 'Sales',
#      'SerialNumbers': None,
#      'BatchNumbers': None,
#      'Guid': '703e6ac9-f6ee-4b0e-95de-911403f3b220',
#      'LastModifiedOn': '/Date(1560796043396)/'},
#     {'LineNumber': 13,
#      'LineType': None,
#      'Product': {'Guid': 'a974872e-b70b-43e0-8efc-1cf8ee594872',
#       'ProductCode': 'NorEdgBlu77840',
#       'ProductDescription': "BlueFire Edger Disks 7' x 7/8' 40 GRIT"},
#      'DueDate': '/Date(1557924550340)/',
#      'OrderQuantity': 300.0,
#      'UnitPrice': 0.99,
#      'DiscountRate': 0.3232,
#      'LineTotal': 201.0,
#      'Volume': None,
#      'Weight': None,
#      'Comments': '',
#      'AverageLandedPriceAtTimeOfSale': 0.54143,
#      'TaxRate': 0.08,
#      'LineTax': 16.08,
#      'XeroTaxCode': 'Niagara County',
#      'BCUnitPrice': 0.67,
#      'BCLineTotal': 201.0,
#      'BCLineTax': 16.08,
#      'LineTaxCode': None,
#      'XeroSalesAccount': 'Sales',
#      'SerialNumbers': None,
#      'BatchNumbers': None,
#      'Guid': '76a1fafe-b8e6-4afb-a46b-89409665843d',
#      'LastModifiedOn': '/Date(1560796043412)/'},
#     {'LineNumber': 14,
#      'LineType': None,
#      'Product': {'Guid': 'd9d2a822-6849-46f0-831e-86ceeb828aee',
#       'ProductCode': 'NorEdgBlu77850',
#       'ProductDescription': "BlueFire Edger Disks 7' x 7/8' 50 GRIT"},
#      'DueDate': '/Date(1557924550340)/',
#      'OrderQuantity': 225.0,
#      'UnitPrice': 0.89,
#      'DiscountRate': 0.2809,
#      'LineTotal': 144.0,
#      'Volume': None,
#      'Weight': None,
#      'Comments': '',
#      'AverageLandedPriceAtTimeOfSale': 0.53,
#      'TaxRate': 0.08,
#      'LineTax': 11.52,
#      'XeroTaxCode': 'Niagara County',
#      'BCUnitPrice': 0.64,
#      'BCLineTotal': 144.0,
#      'BCLineTax': 11.52,
#      'LineTaxCode': None,
#      'XeroSalesAccount': 'Sales',
#      'SerialNumbers': None,
#      'BatchNumbers': None,
#      'Guid': '18c68c21-609d-4a25-9c6b-65f7de66d637',
#      'LastModifiedOn': '/Date(1560796043412)/'},
#     {'LineNumber': 15,
#      'LineType': None,
#      'Product': {'Guid': 'e8009e54-6b35-49e5-acf2-26ee6ea7b4bd',
#       'ProductCode': 'NorEdgBlu77860',
#       'ProductDescription': "BlueFire Edger Disks 7' x 7/8' 60 GRIT"},
#      'DueDate': '/Date(1557924550340)/',
#      'OrderQuantity': 225.0,
#      'UnitPrice': 0.89,
#      'DiscountRate': 0.3258,
#      'LineTotal': 135.0,
#      'Volume': None,
#      'Weight': None,
#      'Comments': '',
#      'AverageLandedPriceAtTimeOfSale': 0.48,
#      'TaxRate': 0.08,
#      'LineTax': 10.8,
#      'XeroTaxCode': 'Niagara County',
#      'BCUnitPrice': 0.6,
#      'BCLineTotal': 135.0,
#      'BCLineTax': 10.8,
#      'LineTaxCode': None,
#      'XeroSalesAccount': 'Sales',
#      'SerialNumbers': None,
#      'BatchNumbers': None,
#      'Guid': '262519f9-2f74-434a-a796-84f692de9457',
#      'LastModifiedOn': '/Date(1560796043412)/'},
#     {'LineNumber': 16,
#      'LineType': None,
#      'Product': {'Guid': '65283d87-0923-4bba-9813-77f0c1c17c7f',
#       'ProductCode': 'NorEdgBlu77880',
#       'ProductDescription': "BlueFire Edger Disks 7' x 7/8' 80 GRIT"},
#      'DueDate': '/Date(1557924550340)/',
#      'OrderQuantity': 425.0,
#      'UnitPrice': 0.69,
#      'DiscountRate': 0.2899,
#      'LineTotal': 208.25,
#      'Volume': None,
#      'Weight': None,
#      'Comments': '',
#      'AverageLandedPriceAtTimeOfSale': 0.42,
#      'TaxRate': 0.08,
#      'LineTax': 16.66,
#      'XeroTaxCode': 'Niagara County',
#      'BCUnitPrice': 0.49,
#      'BCLineTotal': 208.25,
#      'BCLineTax': 16.66,
#      'LineTaxCode': None,
#      'XeroSalesAccount': 'Sales',
#      'SerialNumbers': None,
#      'BatchNumbers': None,
#      'Guid': '3d03bcb8-3c80-4807-ab9b-f75b24a635d2',
#      'LastModifiedOn': '/Date(1560796043427)/'}],
#    'OrderNumber': 'SO-00004799',
#    'OrderDate': '/Date(1557961200000)/',
#    'RequiredDate': '/Date(1557961200000)/',
#    'CompletedDate': None,
#    'OrderStatus': 'Parked',
#    'Customer': {'CustomerCode': 'JAZZ HARDWOOD',
#     'CustomerName': 'JAZZ HARDWOOD',
#     'CurrencyId': 151,
#     'Guid': 'dee8493a-4194-44b0-9bd9-fd71e1811853',
#     'LastModifiedOn': '/Date(1561398981356)/'},
#    'CustomerRef': 'blue fire',
#    'Comments': 'waiting for confirmation on order -JM',
#    'Warehouse': {'WarehouseCode': 'IW',
#     'WarehouseName': 'Installers Warehouse',
#     'IsDefault': True,
#     'StreetNo': 'Installers Warehouse, Inc.',
#     'AddressLine1': '1677C Lyell Ave.',
#     'AddressLine2': None,
#     'Suburb': None,
#     'City': 'Rochester',
#     'Region': 'NY',
#     'Country': None,
#     'PostCode': '14606',
#     'PhoneNumber': None,
#     'FaxNumber': None,
#     'MobileNumber': None,
#     'DDINumber': None,
#     'ContactName': None,
#     'Obsolete': False,
#     'Guid': 'f8aedb90-413a-4628-b1e4-80b609abe455',
#     'LastModifiedOn': '/Date(1555075989301)/'},
#    'ReceivedDate': None,
#    'DeliveryName': 'JAZZ HARDWOOD',
#    'DeliveryStreetAddress': '397 GOUNDRY ST',
#    'DeliveryStreetAddress2': None,
#    'DeliverySuburb': None,
#    'DeliveryCity': 'N.TONAWANDA',
#    'DeliveryRegion': 'NY',
#    'DeliveryCountry': None,
#    'DeliveryPostCode': '14120',
#    'Currency': {'CurrencyCode': 'USD',
#     'Description': 'United States of America, Dollars',
#     'Guid': '8e4702ad-594b-4e80-9e0c-bfe77b8aa9f6',
#     'LastModifiedOn': '/Date(1513109457456)/'},
#    'ExchangeRate': 1.0,
#    'DiscountRate': 0.0,
#    'Tax': {'TaxCode': 'Niagara County',
#     'Description': None,
#     'TaxRate': 0.08,
#     'CanApplyToExpenses': False,
#     'CanApplyToRevenue': False,
#     'Obsolete': False,
#     'Guid': '00000000-0000-0000-0000-000000000000',
#     'LastModifiedOn': None},
#    'TaxRate': 0.08,
#    'XeroTaxCode': 'Niagara County',
#    'SubTotal': 2643.7,
#    'TaxTotal': 211.5,
#    'Total': 2855.2,
#    'TotalVolume': 0.0,
#    'TotalWeight': 0.0,
#    'BCSubTotal': 2643.7,
#    'BCTaxTotal': 211.5,
#    'BCTotal': 2855.2,
#    'PaymentDueDate': '/Date(1563373643255)/',
#    'AllocateProduct': True,
#    'SalesOrderGroup': None,
#    'DeliveryMethod': None,
#    'SalesPerson': None,
#    'SendAccountingJournalOnly': False,
#    'SourceId': None,
#    'CreatedBy': 'jon@iwhardwood.com',
#    'CreatedOn': '/Date(1557924550354)/',
#    'LastModifiedBy': 'dave@iwhardwood.com',
#    'Guid': '549fa720-75af-4d2e-ba9b-dbcc30f9ef34',
#    'LastModifiedOn': '/Date(1560796043427)/'},
#   {'SalesOrderLines': [{'LineNumber': 1,
#      'LineType': None,
#      'Product': {'Guid': '302f266c-c1b4-4fb6-ae63-3ffc37671d0e',
#       'ProductCode': 'GriROIns212',
#       'ProductDescription': '2 1/2 X 12 R/O Ins Trimline'},
#      'DueDate': '/Date(1559749188003)/',
#      'OrderQuantity': 1.0,
#      'UnitPrice': 12.21,
#      'DiscountRate': 0.0,
#      'LineTotal': 12.21,
#      'Volume': None,
#      'Weight': None,
#      'Comments': '',
#      'AverageLandedPriceAtTimeOfSale': 11.161,
#      'TaxRate': 0.08,
#      'LineTax': 0.98,
#      'XeroTaxCode': 'Monroe County',
#      'BCUnitPrice': 12.21,
#      'BCLineTotal': 12.21,
#      'BCLineTax': 0.98,
#      'LineTaxCode': None,
#      'XeroSalesAccount': 'Sales',
#      'SerialNumbers': None,
#      'BatchNumbers': None,
#      'Guid': 'e8653dd1-4987-470b-8e0a-0c491bc1c5dc',
#      'LastModifiedOn': '/Date(1559749464479)/'},
#     {'LineNumber': 2,
#      'LineType': None,
#      'Product': {'Guid': '295c8961-2437-478b-8d0e-5c19f2880066',
#       'ProductCode': 'NorTriBac778Mar',
#       'ProductDescription': "7-7/8' x 3/16' Maroon Non-Woven"},
#      'DueDate': '/Date(1559749188003)/',
#      'OrderQuantity': 2.0,
#      'UnitPrice': 1.37,
#      'DiscountRate': 0.0,
#      'LineTotal': 2.74,
#      'Volume': None,
#      'Weight': None,
#      'Comments': '',
#      'AverageLandedPriceAtTimeOfSale': 1.26444791666667,
#      'TaxRate': 0.08,
#      'LineTax': 0.22,
#      'XeroTaxCode': 'Monroe County',
#      'BCUnitPrice': 1.37,
#      'BCLineTotal': 2.74,
#      'BCLineTax': 0.22,
#      'LineTaxCode': None,
#      'XeroSalesAccount': 'Sales',
#      'SerialNumbers': None,
#      'BatchNumbers': None,
#      'Guid': '125ead7a-e3d2-46bd-8593-d40b85725c1c',
#      'LastModifiedOn': '/Date(1559749464510)/'},
#     {'LineNumber': 3,
#      'LineType': None,
#      'Product': {'Guid': '3380b1ca-47ad-4c9f-9807-dae19ae7e517',
#       'ProductCode': 'LenPolRapQua',
#       'ProductDescription': 'Lenmar Polyurethane Rapid Sealer Quart'},
#      'DueDate': '/Date(1559749188003)/',
#      'OrderQuantity': 1.0,
#      'UnitPrice': 4.97,
#      'DiscountRate': 0.0,
#      'LineTotal': 4.97,
#      'Volume': None,
#      'Weight': None,
#      'Comments': '',
#      'AverageLandedPriceAtTimeOfSale': 4.64372417982989,
#      'TaxRate': 0.08,
#      'LineTax': 0.4,
#      'XeroTaxCode': 'Monroe County',
#      'BCUnitPrice': 4.97,
#      'BCLineTotal': 4.97,
#      'BCLineTax': 0.4,
#      'LineTaxCode': None,
#      'XeroSalesAccount': 'Sales',
#      'SerialNumbers': None,
#      'BatchNumbers': None,
#      'Guid': 'bd0d870b-44ad-4e4f-9a36-aab3a6824778',
#      'LastModifiedOn': '/Date(1559749464526)/'}],
#    'OrderNumber': 'SO-00004990',
#    'OrderDate': '/Date(1559775600000)/',
#    'RequiredDate': '/Date(1559775600000)/',
#    'CompletedDate': None,
#    'OrderStatus': 'Parked',
#    'Customer': {'CustomerCode': 'Employee',
#     'CustomerName': 'Employee',
#     'CurrencyId': 151,
#     'Guid': 'd5fa239d-ea03-44dc-9dad-aaac2efb04f4',
#     'LastModifiedOn': '/Date(1541688114960)/'},
#    'CustomerRef': 'Sue',
#    'Comments': None,
#    'Warehouse': {'WarehouseCode': 'IW',
#     'WarehouseName': 'Installers Warehouse',
#     'IsDefault': True,
#     'StreetNo': 'Installers Warehouse, Inc.',
#     'AddressLine1': '1677C Lyell Ave.',
#     'AddressLine2': None,
#     'Suburb': None,
#     'City': 'Rochester',
#     'Region': 'NY',
#     'Country': None,
#     'PostCode': '14606',
#     'PhoneNumber': None,
#     'FaxNumber': None,
#     'MobileNumber': None,
#     'DDINumber': None,
#     'ContactName': None,
#     'Obsolete': False,
#     'Guid': 'f8aedb90-413a-4628-b1e4-80b609abe455',
#     'LastModifiedOn': '/Date(1555075989301)/'},
#    'ReceivedDate': None,
#    'DeliveryName': None,
#    'DeliveryStreetAddress': None,
#    'DeliveryStreetAddress2': None,
#    'DeliverySuburb': None,
#    'DeliveryCity': None,
#    'DeliveryRegion': None,
#    'DeliveryCountry': None,
#    'DeliveryPostCode': None,
#    'Currency': {'CurrencyCode': 'USD',
#     'Description': 'United States of America, Dollars',
#     'Guid': '8e4702ad-594b-4e80-9e0c-bfe77b8aa9f6',
#     'LastModifiedOn': '/Date(1513109457456)/'},
#    'ExchangeRate': 1.0,
#    'DiscountRate': 0.0,
#    'Tax': {'TaxCode': 'Monroe County',
#     'Description': None,
#     'TaxRate': 0.08,
#     'CanApplyToExpenses': False,
#     'CanApplyToRevenue': False,
#     'Obsolete': False,
#     'Guid': '00000000-0000-0000-0000-000000000000',
#     'LastModifiedOn': None},
#    'TaxRate': 0.08,
#    'XeroTaxCode': 'Monroe County',
#    'SubTotal': 19.92,
#    'TaxTotal': 1.6,
#    'Total': 21.52,
#    'TotalVolume': 0.0,
#    'TotalWeight': 0.0,
#    'BCSubTotal': 19.92,
#    'BCTaxTotal': 1.6,
#    'BCTotal': 21.52,
#    'PaymentDueDate': '/Date(1559735064432)/',
#    'AllocateProduct': True,
#    'SalesOrderGroup': None,
#    'DeliveryMethod': None,
#    'SalesPerson': None,
#    'SendAccountingJournalOnly': False,
#    'SourceId': None,
#    'CreatedBy': 'sue@iwhardwood.com',
#    'CreatedOn': '/Date(1559749188018)/',
#    'LastModifiedBy': 'sue@iwhardwood.com',
#    'Guid': '639c5e89-c842-46ec-a380-5c0483da1b8e',
#    'LastModifiedOn': '/Date(1559749464541)/'},
#   {'SalesOrderLines': [{'LineNumber': 1,
#      'LineType': None,
#      'Product': {'Guid': 'a5bb8227-dec8-4a41-b902-d181c8b870e2',
#       'ProductCode': 'CumWhi3#1C',
#       'ProductDescription': "White Oak #1Common 3.25'"},
#      'DueDate': '/Date(1553279059720)/',
#      'OrderQuantity': 1319.5,
#      'UnitPrice': 3.39,
#      'DiscountRate': 0.0,
#      'LineTotal': 4473.11,
#      'Volume': None,
#      'Weight': None,
#      'Comments': '',
#      'AverageLandedPriceAtTimeOfSale': 2.48167698967699,
#      'TaxRate': 0.08,
#      'LineTax': 357.85,
#      'XeroTaxCode': 'Monroe County',
#      'BCUnitPrice': 3.39,
#      'BCLineTotal': 4473.11,
#      'BCLineTax': 357.85,
#      'LineTaxCode': None,
#      'XeroSalesAccount': 'Sales',
#      'SerialNumbers': None,
#      'BatchNumbers': None,
#      'Guid': '3dcec02b-7fe0-4433-97f3-ddc35e266258',
#      'LastModifiedOn': '/Date(1553279349033)/'}],
#    'OrderNumber': 'SO-00004176',
#    'OrderDate': '/Date(1553295600000)/',
#    'RequiredDate': '/Date(1553295600000)/',
#    'CompletedDate': None,
#    'OrderStatus': 'Parked',
#    'Customer': {'CustomerCode': 'MIDKNIGHT FLOORING',
#     'CustomerName': 'MIDKNIGHT FLOORING',
#     'CurrencyId': 151,
#     'Guid': '31619668-92b8-48f2-9e7d-3c577ccad066',
#     'LastModifiedOn': '/Date(1561398984611)/'},
#    'CustomerRef': None,
#    'Comments': None,
#    'Warehouse': {'WarehouseCode': 'IW',
#     'WarehouseName': 'Installers Warehouse',
#     'IsDefault': True,
#     'StreetNo': 'Installers Warehouse, Inc.',
#     'AddressLine1': '1677C Lyell Ave.',
#     'AddressLine2': None,
#     'Suburb': None,
#     'City': 'Rochester',
#     'Region': 'NY',
#     'Country': None,
#     'PostCode': '14606',
#     'PhoneNumber': None,
#     'FaxNumber': None,
#     'MobileNumber': None,
#     'DDINumber': None,
#     'ContactName': None,
#     'Obsolete': False,
#     'Guid': 'f8aedb90-413a-4628-b1e4-80b609abe455',
#     'LastModifiedOn': '/Date(1555075989301)/'},
#    'ReceivedDate': None,
#    'DeliveryName': 'MIDKNIGHT FLOORING',
#    'DeliveryStreetAddress': '32 CURTISDALE LANE',
#    'DeliveryStreetAddress2': None,
#    'DeliverySuburb': None,
#    'DeliveryCity': 'HAMLIN',
#    'DeliveryRegion': 'NY',
#    'DeliveryCountry': None,
#    'DeliveryPostCode': '14464',
#    'Currency': {'CurrencyCode': 'USD',
#     'Description': 'United States of America, Dollars',
#     'Guid': '8e4702ad-594b-4e80-9e0c-bfe77b8aa9f6',
#     'LastModifiedOn': '/Date(1513109457456)/'},
#    'ExchangeRate': 1.0,
#    'DiscountRate': 0.0,
#    'Tax': {'TaxCode': 'Monroe County',
#     'Description': None,
#     'TaxRate': 0.08,
#     'CanApplyToExpenses': False,
#     'CanApplyToRevenue': False,
#     'Obsolete': False,
#     'Guid': '00000000-0000-0000-0000-000000000000',
#     'LastModifiedOn': None},
#    'TaxRate': 0.08,
#    'XeroTaxCode': 'Monroe County',
#    'SubTotal': 4473.11,
#    'TaxTotal': 357.85,
#    'Total': 4830.96,
#    'TotalVolume': 0.0,
#    'TotalWeight': 0.0,
#    'BCSubTotal': 4473.11,
#    'BCTaxTotal': 357.85,
#    'BCTotal': 4830.96,
#    'PaymentDueDate': '/Date(1553264948986)/',
#    'AllocateProduct': True,
#    'SalesOrderGroup': None,
#    'DeliveryMethod': None,
#    'SalesPerson': None,
#    'SendAccountingJournalOnly': False,
#    'SourceId': None,
#    'CreatedBy': 'dave@iwhardwood.com',
#    'CreatedOn': '/Date(1553279059749)/',
#    'LastModifiedBy': 'dave@iwhardwood.com',
#    'Guid': '3ef32c86-532c-42d8-af55-003d30c16fcc',
#    'LastModifiedOn': '/Date(1553279349080)/'}]}

# %%
sales_orders_df = pd.read_json(json.dumps(r.json()['Items']))
sales_orders_df[['CreatedOn', 'RequiredDate']].head()
# Out:
#                CreatedOn           RequiredDate
# 0  /Date(1564672510904)/  /Date(1564672510889)/
# 1  /Date(1564584520282)/  /Date(1569020400000)/
# 2  /Date(1564492440829)/  /Date(1564527600000)/
# 3  /Date(1564408903634)/  /Date(1564441200000)/
# 4  /Date(1564409065168)/  /Date(1564441200000)/

# %% [markdown]
# The dates in unleashed come through as a datestamp, so my connection program to unleashed has the function convertDateToDate()

# %%
sales_orders_df.CreatedOn.sales_orders_df.CreatedOn.apply(convertDateToDate)
sales_orders_df.RequiredDate = sales_orders_df.RequiredDate.apply(convertDateToDate)

# %%
sales_orders_df[['CreatedOn', 'RequiredDate']].head()
# Out:
#                 CreatedOn            RequiredDate
# 0 2019-08-01 15:15:10.904 2019-08-01 15:15:10.889
# 1 2019-07-31 14:48:40.282 2019-09-20 23:00:00.000
# 2 2019-07-30 13:14:00.829 2019-07-30 23:00:00.000
# 3 2019-07-29 14:01:43.634 2019-07-29 23:00:00.000
# 4 2019-07-29 14:04:25.168 2019-07-29 23:00:00.000

# %% [markdown]
# #### This is all fine, however, in the sales orders dataframe we can't see the actual items customers want to order
# We must extract the nested json object labeled SalesOrderLines
#
# Let's have a look here::

# %%
sales_orders_df.SalesOrderLines[1]
# Out:
# [{'LineNumber': 1,
#   'LineType': None,
#   'Product': {'Guid': '95437681-d17c-456d-a2f0-b11c9b970ec1',
#    'ProductCode': 'WicAshCan3PyrMat',
#    'ProductDescription': "Can+  Ash 3.25' Pyramide MATTE"},
#   'DueDate': '/Date(1564584520266)/',
#   'OrderQuantity': 860.0,
#   'UnitPrice': 3.59,
#   'DiscountRate': 0.0,
#   'LineTotal': 3087.4,
#   'Volume': None,
#   'Weight': None,
#   'Comments': '',
#   'AverageLandedPriceAtTimeOfSale': 2.80085135135135,
#   'TaxRate': 0.075,
#   'LineTax': 231.56,
#   'XeroTaxCode': 'Ontario County',
#   'BCUnitPrice': 3.59,
#   'BCLineTotal': 3087.4,
#   'BCLineTax': 231.56,
#   'LineTaxCode': None,
#   'XeroSalesAccount': 'Sales',
#   'SerialNumbers': None,
#   'BatchNumbers': None,
#   'Guid': 'e66fab79-1584-48b4-8a07-8f22eb551b28',
#   'LastModifiedOn': '/Date(1564584844385)/'},
#  {'LineNumber': 2,
#   'LineType': None,
#   'Product': {'Guid': '8da1abb5-3d75-4766-a778-b5f660b603ce',
#    'ProductCode': 'ForUndAQU',
#    'ProductDescription': 'AQUABAR'},
#   'DueDate': '/Date(1564584520266)/',
#   'OrderQuantity': 2.0,
#   'UnitPrice': 20.59,
#   'DiscountRate': 0.0,
#   'LineTotal': 41.18,
#   'Volume': None,
#   'Weight': None,
#   'Comments': '',
#   'AverageLandedPriceAtTimeOfSale': 14.93943555555556,
#   'TaxRate': 0.075,
#   'LineTax': 3.09,
#   'XeroTaxCode': 'Ontario County',
#   'BCUnitPrice': 20.59,
#   'BCLineTotal': 41.18,
#   'BCLineTax': 3.09,
#   'LineTaxCode': None,
#   'XeroSalesAccount': 'Sales',
#   'SerialNumbers': None,
#   'BatchNumbers': None,
#   'Guid': 'b5270a9b-ab17-41d2-b069-1cd5fa56713f',
#   'LastModifiedOn': '/Date(1564584844385)/'},
#  {'LineNumber': 3,
#   'LineType': None,
#   'Product': {'Guid': '38f03170-ae4c-469b-b5f7-631db900d10b',
#    'ProductCode': 'WicTouPyr',
#    'ProductDescription': 'Touch Up Kit Pyramide'},
#   'DueDate': '/Date(1564584520266)/',
#   'OrderQuantity': 1.0,
#   'UnitPrice': 26.59,
#   'DiscountRate': 0.0,
#   'LineTotal': 26.59,
#   'Volume': None,
#   'Weight': None,
#   'Comments': '',
#   'AverageLandedPriceAtTimeOfSale': 20.36,
#   'TaxRate': 0.075,
#   'LineTax': 1.99,
#   'XeroTaxCode': 'Ontario County',
#   'BCUnitPrice': 26.59,
#   'BCLineTotal': 26.59,
#   'BCLineTax': 1.99,
#   'LineTaxCode': None,
#   'XeroSalesAccount': 'Sales',
#   'SerialNumbers': None,
#   'BatchNumbers': None,
#   'Guid': '68285b90-faaf-4718-b6ea-10c50a1ed5d0',
#   'LastModifiedOn': '/Date(1564584844385)/'},
#  {'LineNumber': 4,
#   'LineType': None,
#   'Product': {'Guid': '870f5f20-6408-4ff3-a944-45c4744ceb6b',
#    'ProductCode': 'Delivery',
#    'ProductDescription': 'Delivery Fee'},
#   'DueDate': '/Date(1564584520266)/',
#   'OrderQuantity': 1.0,
#   'UnitPrice': 85.0,
#   'DiscountRate': 0.0,
#   'LineTotal': 85.0,
#   'Volume': None,
#   'Weight': None,
#   'Comments': '',
#   'AverageLandedPriceAtTimeOfSale': 0.0,
#   'TaxRate': 0.075,
#   'LineTax': 6.38,
#   'XeroTaxCode': 'Ontario County',
#   'BCUnitPrice': 85.0,
#   'BCLineTotal': 85.0,
#   'BCLineTax': 6.38,
#   'LineTaxCode': None,
#   'XeroSalesAccount': 'Sales',
#   'SerialNumbers': None,
#   'BatchNumbers': None,
#   'Guid': '6921a914-d70a-4e90-9196-ae542637c37b',
#   'LastModifiedOn': '/Date(1564584844385)/'}]

# %% [markdown]
# I found a cool description of how to use json_normalize on the kaggle website here: https://www.kaggle.com/jboysen/quick-tutorial-flatten-nested-json-in-pandas
#
# I hope that helps someone else to understand this utility.

# %%
sales_order_lines_df = json_normalize(r.json()['Items'],record_path='SalesOrderLines', meta=['OrderNumber', 'RequiredDate', 'CreatedOn'])
parked_products = json_normalize(sales_order_lines_df.Product)
sales_order_lines_df['ProductCode'] = parked_products.ProductCode

# %%
sales_order_lines_df.columns
# Out:
# Index(['AverageLandedPriceAtTimeOfSale', 'BCLineTax', 'BCLineTotal',
#        'BCUnitPrice', 'BatchNumbers', 'Comments', 'DiscountRate', 'DueDate',
#        'Guid', 'LastModifiedOn', 'LineNumber', 'LineTax', 'LineTaxCode',
#        'LineTotal', 'LineType', 'OrderQuantity', 'Product', 'SerialNumbers',
#        'TaxRate', 'UnitPrice', 'Volume', 'Weight', 'XeroSalesAccount',
#        'XeroTaxCode', 'OrderNumber', 'RequiredDate', 'CreatedOn',
#        'ProductCode'],
#       dtype='object')

# %%
sales_order_lines_df.head()
# Out:
#    AverageLandedPriceAtTimeOfSale  BCLineTax  BCLineTotal  BCUnitPrice  \
# 0                      132.291694      44.61       557.67     185.8900
# 1                       94.393333      18.77       234.58     117.2899
# 2                       49.910000      12.54       156.78      78.3900
# 3                       52.196250      10.38       129.78      64.8900
# 4                       18.556304       4.67        58.38      29.1899
#
#   BatchNumbers Comments  DiscountRate                DueDate  \
# 0         None                    0.0  /Date(1564672510890)/
# 1         None                    0.0  /Date(1564672510890)/
# 2         None                    0.0  /Date(1564672510890)/
# 3         None                    0.0  /Date(1564672510890)/
# 4         None                    0.0  /Date(1564672510890)/
#
#                                    Guid         LastModifiedOn  ...  TaxRate  \
# 0  475aabb4-45f8-4539-9f0f-fb727916d0f5  /Date(1564674342308)/  ...     0.08
# 1  a81f30b9-7f05-49aa-b991-3a01db606e27  /Date(1564674928806)/  ...     0.08
# 2  6060b38a-dbda-4fc0-b581-febbf515a68d  /Date(1564672739678)/  ...     0.08
# 3  b07f277f-5a80-4099-9f0d-63fc51e7fb2a  /Date(1564672787720)/  ...     0.08
# 4  255e0323-e038-4e3b-accd-8b623443391b  /Date(1564672834819)/  ...     0.08
#
#    UnitPrice Volume  Weight XeroSalesAccount     XeroTaxCode  OrderNumber  \
# 0   185.8900   None    None             None  Niagara County  SO-00005650
# 1   117.2899   None    None             None  Niagara County  SO-00005650
# 2    78.3900   None    None             None  Niagara County  SO-00005650
# 3    64.8900   None    None             None  Niagara County  SO-00005650
# 4    29.1899   None    None             None  Niagara County  SO-00005650
#
#             RequiredDate              CreatedOn     ProductCode
# 0  /Date(1564672510889)/  /Date(1564672510904)/   ZinUniSea5Gal
# 1  /Date(1564672510889)/  /Date(1564672510904)/  GLIWatMaxX2SAT
# 2  /Date(1564672510889)/  /Date(1564672510904)/        Pal96Sat
# 3  /Date(1564672510889)/  /Date(1564672510904)/    GLIWatINFSEM
# 4  /Date(1564672510889)/  /Date(1564672510904)/       WooFT301D
#
# [5 rows x 28 columns]

# %%
sales_order_lines_df.CreatedOn = sales_order_lines_df.CreatedOn.apply(convertDateToDate)
sales_order_lines_df.RequiredDate = sales_order_lines_df.RequiredDate.apply(convertDateToDate)

# %%
sales_order_lines_df.columns
# Out:
# Index(['AverageLandedPriceAtTimeOfSale', 'BCLineTax', 'BCLineTotal',
#        'BCUnitPrice', 'BatchNumbers', 'Comments', 'DiscountRate', 'DueDate',
#        'Guid', 'LastModifiedOn', 'LineNumber', 'LineTax', 'LineTaxCode',
#        'LineTotal', 'LineType', 'OrderQuantity', 'Product', 'SerialNumbers',
#        'TaxRate', 'UnitPrice', 'Volume', 'Weight', 'XeroSalesAccount',
#        'XeroTaxCode', 'OrderNumber', 'RequiredDate', 'CreatedOn',
#        'ProductCode'],
#       dtype='object')

# %%
sales_order_lines_df = sales_order_lines_df[['OrderNumber', 'CreatedOn', 'RequiredDate', 'ProductCode','OrderQuantity']]

# %%
sales_order_lines_df.head(10)
# Out:
#    OrderNumber               CreatedOn            RequiredDate  \
# 0  SO-00005650 2019-08-01 15:15:10.904 2019-08-01 15:15:10.889
# 1  SO-00005650 2019-08-01 15:15:10.904 2019-08-01 15:15:10.889
# 2  SO-00005650 2019-08-01 15:15:10.904 2019-08-01 15:15:10.889
# 3  SO-00005650 2019-08-01 15:15:10.904 2019-08-01 15:15:10.889
# 4  SO-00005650 2019-08-01 15:15:10.904 2019-08-01 15:15:10.889
# 5  SO-00005628 2019-07-31 14:48:40.282 2019-09-20 23:00:00.000
# 6  SO-00005628 2019-07-31 14:48:40.282 2019-09-20 23:00:00.000
# 7  SO-00005628 2019-07-31 14:48:40.282 2019-09-20 23:00:00.000
# 8  SO-00005628 2019-07-31 14:48:40.282 2019-09-20 23:00:00.000
# 9  SO-00005616 2019-07-30 13:14:00.829 2019-07-30 23:00:00.000
#
#         ProductCode  OrderQuantity
# 0     ZinUniSea5Gal            3.0
# 1    GLIWatMaxX2SAT            2.0
# 2          Pal96Sat            2.0
# 3      GLIWatINFSEM            2.0
# 4         WooFT301D            2.0
# 5  WicAshCan3PyrMat          860.0
# 6         ForUndAQU            2.0
# 7         WicTouPyr            1.0
# 8          Delivery            1.0
# 9       GriROIns410            5.0

# %% [markdown]
# #### Now we have a dataframe that displays all the orders that could potentially need to be ordered from their respective manufacturers.
#
# From here, we must check our exisiting inventory to determine which of the sales order lines we might need to purchase.

# %% [markdown]
# ### Checking inventory means getting all the stock we have on hand currently.

# %%
stock_on_hand_df = pd.read_json(json.dumps(getSOH()))

# %% [markdown]
# Now check available quantities of product against parked sales orders

# %%
stock_on_hand_df[stock_on_hand_df.AvailableQty < 0].head()
# Out:
#       AllocatedQty  AvailableQty   AvgCost  DaysSinceLastSale  \
# 2483         40.00        -40.00  4.406127                NaN
# 2716         40.00        -30.00  3.726700               76.0
# 3393         45.50        -45.50  5.745538                NaN
# 4203         25.59        -25.59  0.000000                NaN
#
#                                       Guid         LastModifiedOn  OnPurchase  \
# 2483  b040a1a3-25dc-4793-88ff-9ecaa926934c  /Date(1564243043074)/       40.00
# 2716  4494ddb8-7464-445f-9514-5583346911c4  /Date(1564243043043)/       30.00
# 3393  7b2440aa-5677-4bd8-971c-08e05ff6c7d9  /Date(1563559142185)/       45.50
# 4203  db1e502c-2be1-447d-b69a-59cc6c0a135b  /Date(1544631840110)/       25.59
#
#          ProductCode                          ProductDescription  \
# 2483  NorBufSan16Red                16' Diameter  Red Sanddollar
# 2716  NorScrDur17180        Durite Screens 17' Diameter 180 Grit
# 3393       RWFVinRai                          Railyard White Oak
# 4203    TMCNatBC35/8  BC Prefinished Natural Clear 3 5/8' x 3/4'
#
#           ProductGroupName                           ProductGuid  \
# 2483      Sandpaper-Buffer  b040a1a3-25dc-4793-88ff-9ecaa926934c
# 2716     Sandpaper-Screens  4494ddb8-7464-445f-9514-5583346911c4
# 3393  Prefinished Flooring  7b2440aa-5677-4bd8-971c-08e05ff6c7d9
# 4203   Unfinished Flooring  db1e502c-2be1-447d-b69a-59cc6c0a135b
#
#       ProductSourceId  QtyOnHand  TotalCost  Warehouse WarehouseCode  \
# 2483              NaN          0      0.000  Drop Ship            DS
# 2716              NaN         10     37.267  Drop Ship            DS
# 3393              NaN          0      0.000  Drop Ship            DS
# 4203              NaN          0      0.000  Drop Ship            DS
#
#                                WarehouseId
# 2483  b766007f-c8c7-4f23-bfdc-674c1d81ab40
# 2716  b766007f-c8c7-4f23-bfdc-674c1d81ab40
# 3393  b766007f-c8c7-4f23-bfdc-674c1d81ab40
# 4203  b766007f-c8c7-4f23-bfdc-674c1d81ab40

# %% [markdown]
#  #### Here, we are going to use a simple for loop

# %%
products = sales_order_lines_df.ProductCode.values

# %%
so_to_order = []
for idx, row in sales_order_lines_df.iterrows():
    temp = stock_on_hand_df[stock_on_hand_df['ProductCode'] == row['ProductCode']]
    print(temp)
    if (temp.AvailableQty + temp.OnPurchase) > 0:
        so_to_order.append([row['OrderNumber'], row['ProductCode'], row['OrderQty'], row['RequiredDate']])
# Out:
#       AllocatedQty  AvailableQty     AvgCost  DaysSinceLastSale  \
# 6168           0.0           0.0  132.291694                NaN
#
#                                       Guid         LastModifiedOn  OnPurchase  \
# 6168  876df01f-8f1c-437e-9cec-a3d1b96368e9  /Date(1564674123468)/         0.0
#
#         ProductCode               ProductDescription ProductGroupName  \
# 6168  ZinUniSea5Gal  Universal Sealer 5 Gal Sealcoat           Finish
#
#                                ProductGuid  ProductSourceId  QtyOnHand  \
# 6168  876df01f-8f1c-437e-9cec-a3d1b96368e9              NaN          0
#
#       TotalCost  Warehouse WarehouseCode                           WarehouseId
# 6168        0.0  Drop Ship            DS  b766007f-c8c7-4f23-bfdc-674c1d81ab40
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-165-11162f3d5d46> in <module>()
#       3     temp = stock_on_hand_df[stock_on_hand_df['ProductCode'] == row['ProductCode']]
#       4     print(temp)
# ----> 5     if (temp.AvailableQty + temp.OnPurchase) > 0:
#       6         so_to_order.append([row['OrderNumber'], row['ProductCode'], row['OrderQty'], row['RequiredDate']])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1476         raise ValueError("The truth value of a {0} is ambiguous. "
#    1477                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1478                          .format(self.__class__.__name__))
#    1479
#    1480     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
